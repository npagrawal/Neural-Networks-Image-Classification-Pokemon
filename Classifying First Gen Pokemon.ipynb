# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from keras.preprocessing import image

import os
import random
import shutil
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout 
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import EarlyStopping

# %%
path = "data/dataset"
class_labels = os.listdir(path)

image_list = []
for label in class_labels:
    label_dir = os.path.join(path, label)
    images = os.listdir(label_dir)
    image_list.append(images)

# %%
class_labels = os.listdir(path)
class_labels.remove('.ipynb_checkpoints')
class_labels
# Out:
# ['Zapdos',
#  'Kadabra',
#  'Omanyte',
#  'Shellder',
#  'Bellsprout',
#  'Eevee',
#  'Jolteon',
#  'Hypno',
#  'Seel',
#  'Zubat',
#  'Graveler',
#  'Magneton',
#  'Abra',
#  'Kingler',
#  'Alakazam',
#  'Clefable',
#  'Gyarados',
#  'Poliwag',
#  'Rapidash',
#  'Machamp',
#  'Pinsir',
#  'Muk',
#  'Seaking',
#  'Magikarp',
#  'Goldeen',
#  'Venusaur',
#  'Flareon',
#  'Jigglypuff',
#  'Doduo',
#  'Weedle',
#  'Vileplume',
#  'Arcanine',
#  'Tentacruel',
#  'Gloom',
#  'Charmeleon',
#  'Articuno',
#  'Sandshrew',
#  'Spearow',
#  'Marowak',
#  'Clefairy',
#  'Snorlax',
#  'Scyther',
#  'Primeape',
#  'Diglett',
#  'Onix',
#  'Mankey',
#  'Rattata',
#  'Voltorb',
#  'Gengar',
#  'Gastly',
#  'Cloyster',
#  'Weepinbell',
#  'Dragonair',
#  'Squirtle',
#  'Pikachu',
#  'Victreebel',
#  'Charmander',
#  'Staryu',
#  'Venonat',
#  'Vaporeon',
#  'Ivysaur',
#  'Krabby',
#  'Drowzee',
#  'Sandslash',
#  'Kangaskhan',
#  'Chansey',
#  'Butterfree',
#  'Starmie',
#  'Magmar',
#  'Beedrill',
#  'Ninetales',
#  'Magnemite',
#  'Metapod',
#  'Electrode',
#  'Raichu',
#  'Fearow',
#  'Mewtwo',
#  'Kabuto',
#  'Pidgeotto',
#  'Hitmonchan',
#  'Blastoise',
#  'Weezing',
#  'Golbat',
#  'Seadra',
#  'Rhyhorn',
#  'Moltres',
#  'Golduck',
#  'Kabutops',
#  'Aerodactyl',
#  'Haunter',
#  'Machop',
#  'Koffing',
#  'Pidgeot',
#  'Wigglytuff',
#  'Porygon',
#  'Vulpix',
#  'Dugtrio',
#  'Ditto',
#  'Raticate',
#  'Geodude',
#  'Tentacool',
#  'Horsea',
#  'Oddish',
#  'Machoke',
#  'Lapras',
#  'Poliwrath',
#  'Omastar',
#  'Slowpoke',
#  'Bulbasaur',
#  'Growlithe',
#  'Ponyta',
#  'Parasect',
#  'Dodrio',
#  'Meowth',
#  'Exeggutor',
#  'Persian',
#  'Psyduck',
#  'Tauros',
#  'Pidgey',
#  'Electabuzz',
#  'Dewgong',
#  'Wartortle',
#  'Nidoking',
#  'Grimer',
#  'Ekans',
#  'Caterpie',
#  'Tangela',
#  'Kakuna',
#  'Golem',
#  'Slowbro',
#  'MrMime',
#  'Jynx',
#  'Mew',
#  'Paras',
#  'Hitmonlee',
#  'Exeggcute',
#  'Arbok',
#  'Venomoth',
#  'Dratini',
#  'Cubone',
#  'Rhydon',
#  'Dragonite',
#  'Nidorino',
#  'Lickitung',
#  'Nidorina',
#  'Charizard',
#  'Poliwhirl',
#  'Nidoqueen',
#  'Farfetchd']

# %%
image_list = [item for sublist in image_list for item in sublist]
image_list
# Out:
# ['dataset_Zapdos9.jpg',
#  'dataset_Zapdos8.jpg',
#  'dataset_Zapdos12.jpg',
#  'dataset_Zapdos13.jpg',
#  'dataset_Zapdos11.jpg',
#  'dataset_Zapdos10.jpg',
#  'dataset_Zapdos28.jpg',
#  'dataset_Zapdos14.jpg',
#  'dataset_Zapdos15.jpg',
#  'dataset_Zapdos29.jpg',
#  'dataset_Zapdos17.jpg',
#  'dataset_Zapdos16.jpg',
#  'dataset_Zapdos27.jpg',
#  'dataset_Zapdos32.jpg',
#  'dataset_Zapdos26.jpg',
#  'dataset_Zapdos30.jpg',
#  'dataset_Zapdos24.jpg',
#  'dataset_Zapdos18.jpg',
#  'dataset_Zapdos19.jpg',
#  'dataset_Zapdos25.jpg',
#  'dataset_Zapdos31.jpg',
#  'dataset_Zapdos21.jpg',
#  'dataset_Zapdos20.jpg',
#  'dataset_Zapdos22.jpg',
#  'dataset_Zapdos23.jpg',
#  'dataset_Zapdos3.jpg',
#  'dataset_Zapdos2.jpg',
#  'dataset_Zapdos1.jpg',
#  'dataset_Zapdos5.jpg',
#  'dataset_Zapdos4.jpg',
#  'dataset_Zapdos6.jpg',
#  'dataset_Zapdos7.jpg',
#  'dataset_Zapdos33.svg',
#  'dataset_Kadabra40.jpeg',
#  'dataset_Kadabra35.jpg',
#  'dataset_Kadabra21.jpg',
#  'dataset_Kadabra20.jpg',
#  'dataset_Kadabra34.jpg',
#  'dataset_Kadabra22.jpg',
#  'dataset_Kadabra36.jpg',
#  'dataset_Kadabra37.jpg',
#  'dataset_Kadabra23.jpg',
#  'dataset_Kadabra27.jpg',
#  'dataset_Kadabra33.jpg',
#  'dataset_Kadabra32.jpg',
#  'dataset_Kadabra26.jpg',
#  'dataset_Kadabra18.jpg',
#  'dataset_Kadabra30.jpg',
#  'dataset_Kadabra24.jpg',
#  'dataset_Kadabra25.jpg',
#  'dataset_Kadabra31.jpg',
#  'dataset_Kadabra19.jpg',
#  'dataset_Kadabra7.jpg',
#  'dataset_Kadabra6.jpg',
#  'dataset_Kadabra4.jpg',
#  'dataset_Kadabra5.jpg',
#  'dataset_Kadabra1.jpg',
#  'dataset_Kadabra2.jpg',
#  'dataset_Kadabra3.jpg',
#  'dataset_Kadabra8.jpg',
#  'dataset_Kadabra9.jpg',
#  'dataset_Kadabra14.jpg',
#  'dataset_Kadabra28.jpg',
#  'dataset_Kadabra29.jpg',
#  'dataset_Kadabra15.jpg',
#  'dataset_Kadabra17.jpg',
#  'dataset_Kadabra16.jpg',
#  'dataset_Kadabra12.jpg',
#  'dataset_Kadabra13.jpg',
#  'dataset_Kadabra39.jpg',
#  'dataset_Kadabra11.jpg',
#  'dataset_Kadabra10.jpg',
#  'dataset_Kadabra38.jpg',
#  'dataset_Omanyte11.jpg',
#  'dataset_Omanyte10.jpg',
#  'dataset_Omanyte8.jpg',
#  'dataset_Omanyte12.jpg',
#  'dataset_Omanyte13.jpg',
#  'dataset_Omanyte9.jpg',
#  'dataset_Omanyte17.jpg',
#  'dataset_Omanyte16.jpg',
#  'dataset_Omanyte14.jpg',
#  'dataset_Omanyte28.jpg',
#  'dataset_Omanyte29.jpg',
#  'dataset_Omanyte15.jpg',
#  'dataset_Omanyte2.jpg',
#  'dataset_Omanyte18.jpg',
#  'dataset_Omanyte24.jpg',
#  'dataset_Omanyte30.jpg',
#  'dataset_Omanyte25.jpg',
#  'dataset_Omanyte19.jpg',
#  'dataset_Omanyte3.jpg',
#  'dataset_Omanyte1.jpg',
#  'dataset_Omanyte27.jpg',
#  'dataset_Omanyte26.jpg',
#  'dataset_Omanyte22.jpg',
#  'dataset_Omanyte4.jpg',
#  'dataset_Omanyte5.jpg',
#  'dataset_Omanyte23.jpg',
#  'dataset_Omanyte21.jpg',
#  'dataset_Omanyte7.jpg',
#  'dataset_Omanyte6.jpg',
#  'dataset_Omanyte20.jpg',
#  'dataset_Shellder2.jpg',
#  'dataset_Shellder16.jpg',
#  'dataset_Shellder17.jpg',
#  'dataset_Shellder3.jpg',
#  'dataset_Shellder1.jpg',
#  'dataset_Shellder29.jpg',
#  'dataset_Shellder15.jpg',
#  'dataset_Shellder14.jpg',
#  'dataset_Shellder28.jpg',
#  'dataset_Shellder4.jpg',
#  'dataset_Shellder10.jpg',
#  'dataset_Shellder38.jpg',
#  'dataset_Shellder39.jpg',
#  'dataset_Shellder11.jpg',
#  'dataset_Shellder5.jpg',
#  'dataset_Shellder7.jpg',
#  'dataset_Shellder13.jpg',
#  'dataset_Shellder12.jpg',
#  'dataset_Shellder6.jpg',
#  'dataset_Shellder37.jpg',
#  'dataset_Shellder23.jpg',
#  'dataset_Shellder22.jpg',
#  'dataset_Shellder36.jpg',
#  'dataset_Shellder8.jpg',
#  'dataset_Shellder20.jpg',
#  'dataset_Shellder34.jpg',
#  'dataset_Shellder35.jpg',
#  'dataset_Shellder21.jpg',
#  'dataset_Shellder9.jpg',
#  'dataset_Shellder25.jpg',
#  'dataset_Shellder31.jpg',
#  'dataset_Shellder19.jpg',
#  'dataset_Shellder18.jpg',
#  'dataset_Shellder30.jpg',
#  'dataset_Shellder24.jpg',
#  'dataset_Shellder32.jpg',
#  'dataset_Shellder26.jpg',
#  'dataset_Shellder27.jpg',
#  'dataset_Shellder33.jpg',
#  'dataset_Bellsprout24.jpg',
#  'dataset_Bellsprout30.jpg',
#  'dataset_Bellsprout18.jpg',
#  'dataset_Bellsprout4.jpg',
#  'dataset_Bellsprout5.jpg',
#  'dataset_Bellsprout19.jpg',
#  'dataset_Bellsprout31.jpg',
#  'dataset_Bellsprout25.jpg',
#  'dataset_Bellsprout33.jpg',
#  'dataset_Bellsprout27.jpg',
#  'dataset_Bellsprout7.jpg',
#  'dataset_Bellsprout6.jpg',
#  'dataset_Bellsprout26.jpg',
#  'dataset_Bellsprout32.jpg',
#  'dataset_Bellsprout22.jpg',
#  'dataset_Bellsprout2.jpg',
#  'dataset_Bellsprout3.jpg',
#  'dataset_Bellsprout23.jpg',
#  'dataset_Bellsprout21.jpg',
#  'dataset_Bellsprout35.jpg',
#  'dataset_Bellsprout1.jpg',
#  'dataset_Bellsprout34.jpg',
#  'dataset_Bellsprout20.jpg',
#  'dataset_Bellsprout11.jpg',
#  'dataset_Bellsprout10.jpg',
#  'dataset_Bellsprout12.jpg',
#  'dataset_Bellsprout13.jpg',
#  'dataset_Bellsprout17.jpg',
#  'dataset_Bellsprout16.jpg',
#  'dataset_Bellsprout28.jpg',
#  'dataset_Bellsprout14.jpg',
#  'dataset_Bellsprout8.jpg',
#  'dataset_Bellsprout9.jpg',
#  'dataset_Bellsprout15.jpg',
#  'dataset_Bellsprout29.jpg',
#  'dataset_Eevee8.jpg',
#  'dataset_Eevee9.jpg',
#  'dataset_Eevee19.jpg',
#  'dataset_Eevee18.jpg',
#  'dataset_Eevee24.jpg',
#  'dataset_Eevee23.jpg',
#  'dataset_Eevee22.jpg',
#  'dataset_Eevee20.jpg',
#  'dataset_Eevee21.jpg',
#  'dataset_Eevee10.jpg',
#  'dataset_Eevee11.jpg',
#  'dataset_Eevee13.jpg',
#  'dataset_Eevee12.jpg',
#  'dataset_Eevee16.jpg',
#  'dataset_Eevee17.jpg',
#  'dataset_Eevee15.jpg',
#  'dataset_Eevee14.jpg',
#  'dataset_Eevee4.jpg',
#  'dataset_Eevee5.jpg',
#  'dataset_Eevee7.jpg',
#  'dataset_Eevee6.jpg',
#  'dataset_Eevee2.jpg',
#  'dataset_Eevee3.jpg',
#  'dataset_Eevee1.jpg',
#  'dataset_Jolteon20.jpg',
#  'dataset_Jolteon21.jpg',
#  'dataset_Jolteon23.jpg',
#  'dataset_Jolteon22.jpg',
#  'dataset_Jolteon26.jpg',
#  'dataset_Jolteon27.jpg',
#  'dataset_Jolteon9.jpg',
#  'dataset_Jolteon19.jpg',
#  'dataset_Jolteon31.jpg',
#  'dataset_Jolteon25.jpg',
#  'dataset_Jolteon24.jpg',
#  'dataset_Jolteon30.jpg',
#  'dataset_Jolteon18.jpg',
#  'dataset_Jolteon8.jpg',
#  'dataset_Jolteon5.jpg',
#  'dataset_Jolteon15.jpg',
#  'dataset_Jolteon29.jpg',
#  'dataset_Jolteon28.jpg',
#  'dataset_Jolteon14.jpg',
#  'dataset_Jolteon4.jpg',
#  'dataset_Jolteon6.jpg',
#  'dataset_Jolteon16.jpg',
#  'dataset_Jolteon17.jpg',
#  'dataset_Jolteon7.jpg',
#  'dataset_Jolteon3.jpg',
#  'dataset_Jolteon13.jpg',
#  'dataset_Jolteon12.jpg',
#  'dataset_Jolteon2.jpg',
#  'dataset_Jolteon10.jpg',
#  'dataset_Jolteon11.jpg',
#  'dataset_Jolteon1.jpg',
#  'dataset_Hypno1.jpg',
#  'dataset_Hypno26.svg',
#  'dataset_Hypno2.jpg',
#  'dataset_Hypno3.jpg',
#  'dataset_Hypno7.jpg',
#  'dataset_Hypno6.jpg',
#  'dataset_Hypno4.jpg',
#  'dataset_Hypno5.jpg',
#  'dataset_Hypno22.jpg',
#  'dataset_Hypno23.jpg',
#  'dataset_Hypno21.jpg',
#  'dataset_Hypno20.jpg',
#  'dataset_Hypno24.jpg',
#  'dataset_Hypno18.jpg',
#  'dataset_Hypno19.jpg',
#  'dataset_Hypno25.jpg',
#  'dataset_Hypno17.jpg',
#  'dataset_Hypno16.jpg',
#  'dataset_Hypno14.jpg',
#  'dataset_Hypno15.jpg',
#  'dataset_Hypno11.jpg',
#  'dataset_Hypno10.jpg',
#  'dataset_Hypno12.jpg',
#  'dataset_Hypno13.jpg',
#  'dataset_Hypno8.jpg',
#  'dataset_Hypno9.jpg',
#  'dataset_Seel27.jpg',
#  'dataset_Seel33.jpg',
#  'dataset_Seel32.jpg',
#  'dataset_Seel26.jpg',
#  'dataset_Seel18.jpg',
#  'dataset_Seel30.jpg',
#  'dataset_Seel24.jpg',
#  'dataset_Seel25.jpg',
#  'dataset_Seel31.jpg',
#  'dataset_Seel19.jpg',
#  'dataset_Seel35.jpg',
#  'dataset_Seel21.jpg',
#  'dataset_Seel20.jpg',
#  'dataset_Seel34.jpg',
#  'dataset_Seel22.jpg',
#  'dataset_Seel36.jpg',
#  'dataset_Seel37.jpg',
#  'dataset_Seel23.jpg',
#  'dataset_Seel1.jpg',
#  'dataset_Seel3.jpg',
#  'dataset_Seel2.jpg',
#  'dataset_Seel6.jpg',
#  'dataset_Seel7.jpg',
#  'dataset_Seel5.jpg',
#  'dataset_Seel40.jpg',
#  'dataset_Seel4.jpg',
#  'dataset_Seel9.jpg',
#  'dataset_Seel8.jpg',
#  'dataset_Seel12.jpg',
#  'dataset_Seel13.jpg',
#  'dataset_Seel39.jpg',
#  'dataset_Seel11.jpg',
#  'dataset_Seel10.jpg',
#  'dataset_Seel38.jpg',
#  'dataset_Seel14.jpg',
#  'dataset_Seel28.jpg',
#  'dataset_Seel29.jpg',
#  'dataset_Seel15.jpg',
#  'dataset_Seel17.jpg',
#  'dataset_Seel16.jpg',
#  'dataset_Zubat24.jpg',
#  'dataset_Zubat18.jpg',
#  'dataset_Zubat19.jpg',
#  'dataset_Zubat25.jpg',
#  'dataset_Zubat8.jpg',
#  'dataset_Zubat27.jpg',
#  'dataset_Zubat26.jpg',
#  'dataset_Zubat9.jpg',
#  'dataset_Zubat22.jpg',
#  'dataset_Zubat23.jpg',
#  'dataset_Zubat21.jpg',
#  'dataset_Zubat20.jpg',
#  'dataset_Zubat2.jpg',
#  'dataset_Zubat11.jpg',
#  'dataset_Zubat10.jpg',
#  'dataset_Zubat3.jpg',
#  'dataset_Zubat1.jpg',
#  'dataset_Zubat12.jpg',
#  'dataset_Zubat13.jpg',
#  'dataset_Zubat4.jpg',
#  'dataset_Zubat17.jpg',
#  'dataset_Zubat16.jpg',
#  'dataset_Zubat5.jpg',
#  'dataset_Zubat7.jpg',
#  'dataset_Zubat28.jpg',
#  'dataset_Zubat14.jpg',
#  'dataset_Zubat15.jpg',
#  'dataset_Zubat6.jpg',
#  'dataset_Graveler33.jpg',
#  'dataset_Graveler27.jpg',
#  'dataset_Graveler26.jpg',
#  'dataset_Graveler32.jpg',
#  'dataset_Graveler18.jpg',
#  'dataset_Graveler24.jpg',
#  'dataset_Graveler30.jpg',
#  'dataset_Graveler31.jpg',
#  'dataset_Graveler25.jpg',
#  'dataset_Graveler19.jpg',
#  'dataset_Graveler21.jpg',
#  'dataset_Graveler35.jpg',
#  'dataset_Graveler34.jpg',
#  'dataset_Graveler20.jpg',
#  'dataset_Graveler22.jpg',
#  'dataset_Graveler23.jpg',
#  'dataset_Graveler37.jpg',
#  'dataset_Graveler7.jpg',
#  'dataset_Graveler36.svg',
#  'dataset_Graveler6.jpg',
#  'dataset_Graveler4.jpg',
#  'dataset_Graveler5.jpg',
#  'dataset_Graveler1.jpg',
#  'dataset_Graveler2.jpg',
#  'dataset_Graveler3.jpg',
#  'dataset_Graveler8.jpg',
#  'dataset_Graveler9.jpg',
#  'dataset_Graveler12.jpg',
#  'dataset_Graveler13.jpg',
#  'dataset_Graveler11.jpg',
#  'dataset_Graveler10.jpg',
#  'dataset_Graveler38.jpg',
#  'dataset_Graveler14.jpg',
#  'dataset_Graveler28.jpg',
#  'dataset_Graveler29.jpg',
#  'dataset_Graveler15.jpg',
#  'dataset_Graveler17.jpg',
#  'dataset_Graveler16.jpg',
#  'dataset_Magneton1.jpg',
#  'dataset_Magneton3.jpg',
#  'dataset_Magneton2.jpg',
#  'dataset_Magneton6.jpg',
#  'dataset_Magneton22.svg',
#  'dataset_Magneton7.jpg',
#  'dataset_Magneton5.jpg',
#  'dataset_Magneton4.jpg',
#  'dataset_Magneton21.jpg',
#  'dataset_Magneton20.jpg',
#  'dataset_Magneton23.jpg',
#  'dataset_Magneton18.jpg',
#  'dataset_Magneton24.jpg',
#  'dataset_Magneton14.jpg',
#  'dataset_Magneton15.jpg',
#  'dataset_Magneton17.jpg',
#  'dataset_Magneton16.jpg',
#  'dataset_Magneton12.jpg',
#  'dataset_Magneton13.jpg',
#  'dataset_Magneton11.jpg',
#  'dataset_Magneton10.jpg',
#  'dataset_Magneton9.jpg',
#  'dataset_Magneton8.jpg',
#  'dataset_Abra10.jpg',
#  'dataset_Abra8.jpg',
#  'dataset_Abra9.jpg',
#  'dataset_Abra11.jpg',
#  'dataset_Abra13.jpg',
#  'dataset_Abra12.jpg',
#  'dataset_Abra16.jpg',
#  'dataset_Abra17.jpg',
#  'dataset_Abra15.jpg',
#  'dataset_Abra14.jpeg',
#  'dataset_Abra19.jpg',
#  'dataset_Abra25.jpg',
#  'dataset_Abra1.jpg',
#  'dataset_Abra24.jpg',
#  'dataset_Abra18.jpg',
#  'dataset_Abra26.jpg',
#  'dataset_Abra2.jpg',
#  'dataset_Abra3.jpg',
#  'dataset_Abra27.jpg',
#  'dataset_Abra23.jpg',
#  'dataset_Abra7.jpg',
#  'dataset_Abra6.jpg',
#  'dataset_Abra22.jpg',
#  'dataset_Abra20.jpg',
#  'dataset_Abra4.jpg',
#  'dataset_Abra5.jpg',
#  'dataset_Abra21.jpg',
#  'dataset_Kingler17.jpg',
#  'dataset_Kingler16.jpg',
#  'dataset_Kingler14.jpg',
#  'dataset_Kingler28.jpg',
#  'dataset_Kingler29.jpg',
#  'dataset_Kingler15.jpg',
#  'dataset_Kingler39.jpg',
#  'dataset_Kingler11.jpg',
#  'dataset_Kingler10.jpg',
#  'dataset_Kingler38.jpg',
#  'dataset_Kingler12.jpg',
#  'dataset_Kingler13.jpg',
#  'dataset_Kingler9.jpg',
#  'dataset_Kingler8.jpg',
#  'dataset_Kingler5.jpg',
#  'dataset_Kingler4.jpg',
#  'dataset_Kingler40.jpg',
#  'dataset_Kingler6.jpg',
#  'dataset_Kingler7.jpg',
#  'dataset_Kingler3.jpg',
#  'dataset_Kingler2.jpg',
#  'dataset_Kingler1.jpg',
#  'dataset_Kingler22.jpg',
#  'dataset_Kingler23.jpg',
#  'dataset_Kingler37.jpg',
#  'dataset_Kingler21.jpg',
#  'dataset_Kingler35.jpg',
#  'dataset_Kingler34.jpg',
#  'dataset_Kingler20.jpg',
#  'dataset_Kingler18.jpg',
#  'dataset_Kingler24.jpg',
#  'dataset_Kingler30.jpg',
#  'dataset_Kingler31.jpg',
#  'dataset_Kingler25.jpg',
#  'dataset_Kingler19.jpg',
#  'dataset_Kingler33.jpg',
#  'dataset_Kingler27.jpg',
#  'dataset_Kingler26.jpg',
#  'dataset_Kingler32.jpg',
#  'dataset_Kingler41.svg',
#  'dataset_Alakazam7.jpg',
#  'dataset_Alakazam5.jpg',
#  'dataset_Alakazam4.jpg',
#  'dataset_Alakazam1.jpg',
#  'dataset_Alakazam3.jpg',
#  'dataset_Alakazam2.jpg',
#  'dataset_Alakazam17.jpg',
#  'dataset_Alakazam6.jpeg',
#  'dataset_Alakazam16.jpg',
#  'dataset_Alakazam14.jpg',
#  'dataset_Alakazam15.jpg',
#  'dataset_Alakazam11.jpg',
#  'dataset_Alakazam10.jpg',
#  'dataset_Alakazam12.jpg',
#  'dataset_Alakazam13.jpg',
#  'dataset_Alakazam18.jpg',
#  'dataset_Alakazam19.jpg',
#  'dataset_Alakazam9.jpg',
#  'dataset_Alakazam8.jpg',
#  'dataset_Clefable2.jpg',
#  'dataset_Clefable3.jpg',
#  'dataset_Clefable1.jpg',
#  'dataset_Clefable4.jpg',
#  'dataset_Clefable5.jpg',
#  'dataset_Clefable7.jpg',
#  'dataset_Clefable6.jpg',
#  'dataset_Clefable24.jpg',
#  'dataset_Clefable18.jpg',
#  'dataset_Clefable19.jpg',
#  'dataset_Clefable25.jpg',
#  'dataset_Clefable27.jpg',
#  'dataset_Clefable26.jpg',
#  'dataset_Clefable22.jpg',
#  'dataset_Clefable23.jpg',
#  'dataset_Clefable21.jpg',
#  'dataset_Clefable20.jpg',
#  'dataset_Clefable11.jpg',
#  'dataset_Clefable10.jpg',
#  'dataset_Clefable12.jpg',
#  'dataset_Clefable13.jpg',
#  'dataset_Clefable17.jpg',
#  'dataset_Clefable16.jpg',
#  'dataset_Clefable14.jpg',
#  'dataset_Clefable15.jpg',
#  'dataset_Clefable8.jpg',
#  'dataset_Clefable9.jpg',
#  'dataset_Gyarados5.jpg',
#  'dataset_Gyarados4.jpg',
#  'dataset_Gyarados6.jpg',
#  'dataset_Gyarados7.jpg',
#  'dataset_Gyarados3.jpg',
#  'dataset_Gyarados2.jpg',
#  'dataset_Gyarados1.jpg',
#  'dataset_Gyarados13.jpg',
#  'dataset_Gyarados12.jpg',
#  'dataset_Gyarados10.jpg',
#  'dataset_Gyarados11.jpg',
#  'dataset_Gyarados15.jpg',
#  'dataset_Gyarados14.jpg',
#  'dataset_Gyarados16.jpg',
#  'dataset_Gyarados17.jpg',
#  'dataset_Gyarados19.jpg',
#  'dataset_Gyarados18.jpg',
#  'dataset_Gyarados20.jpg',
#  'dataset_Gyarados22.jpg',
#  'dataset_Gyarados21.svg',
#  'dataset_Gyarados9.jpg',
#  'dataset_Gyarados8.jpg',
#  'dataset_Poliwag1.jpg',
#  'dataset_Poliwag14.jpg',
#  'dataset_Poliwag28.jpg',
#  'dataset_Poliwag29.jpg',
#  'dataset_Poliwag15.jpg',
#  'dataset_Poliwag2.jpg',
#  'dataset_Poliwag17.jpg',
#  'dataset_Poliwag16.jpg',
#  'dataset_Poliwag3.jpg',
#  'dataset_Poliwag7.jpg',
#  'dataset_Poliwag12.jpg',
#  'dataset_Poliwag13.jpg',
#  'dataset_Poliwag6.jpg',
#  'dataset_Poliwag37.jpeg',
#  'dataset_Poliwag4.jpg',
#  'dataset_Poliwag39.jpg',
#  'dataset_Poliwag11.jpg',
#  'dataset_Poliwag10.jpg',
#  'dataset_Poliwag38.jpg',
#  'dataset_Poliwag5.jpg',
#  'dataset_Poliwag8.jpg',
#  'dataset_Poliwag35.jpg',
#  'dataset_Poliwag21.jpg',
#  'dataset_Poliwag20.jpg',
#  'dataset_Poliwag34.jpg',
#  'dataset_Poliwag9.jpg',
#  'dataset_Poliwag36.jpg',
#  'dataset_Poliwag22.jpeg',
#  'dataset_Poliwag23.jpg',
#  'dataset_Poliwag27.jpg',
#  'dataset_Poliwag33.jpg',
#  'dataset_Poliwag40.svg',
#  'dataset_Poliwag32.jpg',
#  'dataset_Poliwag26.jpg',
#  'dataset_Poliwag18.jpg',
#  'dataset_Poliwag30.jpg',
#  'dataset_Poliwag24.jpg',
#  'dataset_Poliwag25.jpg',
#  'dataset_Poliwag31.jpg',
#  'dataset_Poliwag19.jpg',
#  'dataset_Rapidash11.jpg',
#  'dataset_Rapidash39.jpg',
#  'dataset_Rapidash38.jpg',
#  'dataset_Rapidash10.jpg',
#  'dataset_Rapidash12.jpg',
#  'dataset_Rapidash13.jpg',
#  'dataset_Rapidash17.jpg',
#  'dataset_Rapidash16.jpg',
#  'dataset_Rapidash28.jpg',
#  'dataset_Rapidash14.jpg',
#  'dataset_Rapidash15.jpg',
#  'dataset_Rapidash29.jpg',
#  'dataset_Rapidash7.jpg',
#  'dataset_Rapidash6.jpg',
#  'dataset_Rapidash4.jpg',
#  'dataset_Rapidash5.jpg',
#  'dataset_Rapidash1.jpg',
#  'dataset_Rapidash48.jpg',
#  'dataset_Rapidash2.jpg',
#  'dataset_Rapidash3.jpg',
#  'dataset_Rapidash47.jpg',
#  'dataset_Rapidash46.jpg',
#  'dataset_Rapidash44.jpg',
#  'dataset_Rapidash45.jpg',
#  'dataset_Rapidash8.jpg',
#  'dataset_Rapidash41.jpg',
#  'dataset_Rapidash40.jpg',
#  'dataset_Rapidash9.jpg',
#  'dataset_Rapidash42.jpg',
#  'dataset_Rapidash43.jpg',
#  'dataset_Rapidash30.jpg',
#  'dataset_Rapidash24.jpg',
#  'dataset_Rapidash18.jpg',
#  'dataset_Rapidash19.jpg',
#  'dataset_Rapidash25.jpg',
#  'dataset_Rapidash31.jpg',
#  'dataset_Rapidash27.jpg',
#  'dataset_Rapidash33.jpg',
#  'dataset_Rapidash32.jpg',
#  'dataset_Rapidash26.jpg',
#  'dataset_Rapidash22.jpg',
#  'dataset_Rapidash36.jpg',
#  'dataset_Rapidash37.jpg',
#  'dataset_Rapidash23.jpg',
#  'dataset_Rapidash35.jpg',
#  'dataset_Rapidash21.jpg',
#  'dataset_Rapidash20.jpg',
#  'dataset_Rapidash34.jpg',
#  'dataset_Machamp14.jpg',
#  'dataset_Machamp28.jpg',
#  'dataset_Machamp9.jpg',
#  'dataset_Machamp8.jpg',
#  'dataset_Machamp29.jpg',
#  'dataset_Machamp15.jpg',
#  'dataset_Machamp17.jpg',
#  'dataset_Machamp16.jpg',
#  'dataset_Machamp12.jpg',
#  'dataset_Machamp13.jpg',
#  'dataset_Machamp39.jpg',
#  'dataset_Machamp11.jpg',
#  'dataset_Machamp10.jpg',
#  'dataset_Machamp38.jpg',
#  'dataset_Machamp42.jpg',
#  'dataset_Machamp43.jpg',
#  'dataset_Machamp41.jpg',
#  'dataset_Machamp40.jpg',
#  'dataset_Machamp44.jpg',
#  'dataset_Machamp45.jpg',
#  'dataset_Machamp35.svg',
#  'dataset_Machamp46.jpg',
#  'dataset_Machamp21.jpg',
#  'dataset_Machamp1.jpg',
#  'dataset_Machamp34.jpg',
#  'dataset_Machamp20.jpg',
#  'dataset_Machamp36.jpg',
#  'dataset_Machamp22.jpg',
#  'dataset_Machamp3.jpg',
#  'dataset_Machamp2.jpg',
#  'dataset_Machamp23.jpg',
#  'dataset_Machamp37.jpg',
#  'dataset_Machamp33.jpg',
#  'dataset_Machamp27.jpg',
#  'dataset_Machamp6.jpg',
#  'dataset_Machamp7.jpg',
#  'dataset_Machamp26.jpg',
#  'dataset_Machamp32.jpg',
#  'dataset_Machamp18.jpg',
#  'dataset_Machamp24.jpg',
#  'dataset_Machamp30.jpg',
#  'dataset_Machamp5.jpg',
#  'dataset_Machamp4.jpg',
#  'dataset_Machamp31.jpg',
#  'dataset_Machamp19.jpg',
#  'dataset_Pinsir9.jpg',
#  'dataset_Pinsir8.jpg',
#  'dataset_Pinsir32.jpg',
#  'dataset_Pinsir26.jpg',
#  'dataset_Pinsir27.jpg',
#  'dataset_Pinsir33.jpg',
#  'dataset_Pinsir19.jpg',
#  'dataset_Pinsir25.jpg',
#  'dataset_Pinsir31.jpg',
#  'dataset_Pinsir30.jpg',
#  'dataset_Pinsir24.jpg',
#  'dataset_Pinsir18.jpg',
#  'dataset_Pinsir20.jpg',
#  'dataset_Pinsir34.jpg',
#  'dataset_Pinsir21.jpg',
#  'dataset_Pinsir23.jpg',
#  'dataset_Pinsir22.jpg',
#  'dataset_Pinsir13.jpg',
#  'dataset_Pinsir12.jpg',
#  'dataset_Pinsir10.jpg',
#  'dataset_Pinsir11.jpg',
#  'dataset_Pinsir15.jpg',
#  'dataset_Pinsir29.jpg',
#  'dataset_Pinsir28.jpg',
#  'dataset_Pinsir14.jpg',
#  'dataset_Pinsir16.jpg',
#  'dataset_Pinsir17.jpg',
#  'dataset_Pinsir1.jpg',
#  'dataset_Pinsir3.jpg',
#  'dataset_Pinsir2.jpg',
#  'dataset_Pinsir6.jpg',
#  'dataset_Pinsir7.jpg',
#  'dataset_Pinsir5.jpg',
#  'dataset_Pinsir4.jpg',
#  'dataset_Muk37.jpg',
#  'dataset_Muk23.jpg',
#  'dataset_Muk22.jpg',
#  'dataset_Muk36.jpg',
#  'dataset_Muk20.jpg',
#  'dataset_Muk34.jpg',
#  'dataset_Muk35.jpg',
#  'dataset_Muk21.jpg',
#  'dataset_Muk25.jpg',
#  'dataset_Muk31.jpg',
#  'dataset_Muk19.jpg',
#  'dataset_Muk18.jpg',
#  'dataset_Muk30.jpg',
#  'dataset_Muk24.jpg',
#  'dataset_Muk32.jpg',
#  'dataset_Muk26.jpg',
#  'dataset_Muk50.asp',
#  'dataset_Muk27.jpg',
#  'dataset_Muk33.jpg',
#  'dataset_Muk40.jpg',
#  'dataset_Muk5.jpg',
#  'dataset_Muk4.jpg',
#  'dataset_Muk41.jpg',
#  'dataset_Muk43.jpg',
#  'dataset_Muk6.jpg',
#  'dataset_Muk7.jpg',
#  'dataset_Muk42.jpg',
#  'dataset_Muk46.jpg',
#  'dataset_Muk3.jpg',
#  'dataset_Muk2.jpg',
#  'dataset_Muk47.jpg',
#  'dataset_Muk51.jpg',
#  'dataset_Muk45.jpg',
#  'dataset_Muk1.jpg',
#  'dataset_Muk44.jpg',
#  'dataset_Muk49.jpg',
#  'dataset_Muk48.jpg',
#  'dataset_Muk9.jpg',
#  'dataset_Muk8.jpg',
#  'dataset_Muk16.jpg',
#  'dataset_Muk17.jpg',
#  'dataset_Muk29.jpg',
#  'dataset_Muk15.jpg',
#  'dataset_Muk14.jpg',
#  'dataset_Muk28.jpg',
#  'dataset_Muk10.jpg',
#  'dataset_Muk38.jpg',
#  'dataset_Muk39.jpg',
#  'dataset_Muk11.jpg',
#  'dataset_Muk13.jpg',
#  'dataset_Seaking13.jpg',
#  'dataset_Seaking7.jpg',
#  'dataset_Seaking6.jpg',
#  'dataset_Seaking12.jpg',
#  'dataset_Seaking10.jpg',
#  'dataset_Seaking4.jpg',
#  'dataset_Seaking5.jpg',
#  'dataset_Seaking11.jpg',
#  'dataset_Seaking15.jpg',
#  'dataset_Seaking1.jpg',
#  'dataset_Seaking14.jpg',
#  'dataset_Seaking16.jpg',
#  'dataset_Seaking2.jpg',
#  'dataset_Seaking3.jpg',
#  'dataset_Seaking17.jpg',
#  'dataset_Seaking18.jpg',
#  'dataset_Seaking8.jpg',
#  'dataset_Seaking9.jpg',
#  'dataset_Magikarp7.jpg',
#  'dataset_Magikarp6.jpg',
#  'dataset_Magikarp4.jpg',
#  'dataset_Magikarp5.jpg',
#  'dataset_Magikarp1.jpg',
#  'dataset_Magikarp2.jpg',
#  'dataset_Magikarp3.jpg',
#  'dataset_Magikarp19.jpg',
#  'dataset_Magikarp25.jpg',
#  'dataset_Magikarp24.jpg',
#  'dataset_Magikarp18.jpg',
#  'dataset_Magikarp26.jpg',
#  'dataset_Magikarp23.jpg',
#  'dataset_Magikarp22.jpg',
#  'dataset_Magikarp20.jpg',
#  'dataset_Magikarp21.jpg',
#  'dataset_Magikarp10.jpg',
#  'dataset_Magikarp11.jpg',
#  'dataset_Magikarp13.jpg',
#  'dataset_Magikarp12.jpg',
#  'dataset_Magikarp16.jpg',
#  'dataset_Magikarp17.jpg',
#  'dataset_Magikarp15.jpg',
#  'dataset_Magikarp14.jpg',
#  'dataset_Magikarp8.jpg',
#  'dataset_Magikarp9.jpg',
#  'dataset_Goldeen9.jpg',
#  'dataset_Goldeen24.jpg',
#  'dataset_Goldeen18.jpg',
#  'dataset_Goldeen19.jpg',
#  'dataset_Goldeen25.jpg',
#  'dataset_Goldeen8.jpg',
#  'dataset_Goldeen27.jpg',
#  'dataset_Goldeen26.jpg',
#  'dataset_Goldeen22.jpg',
#  'dataset_Goldeen23.jpg',
#  'dataset_Goldeen21.jpg',
#  'dataset_Goldeen20.jpg',
#  'dataset_Goldeen11.jpg',
#  'dataset_Goldeen10.jpg',
#  'dataset_Goldeen1.jpg',
#  'dataset_Goldeen3.jpg',
#  'dataset_Goldeen12.jpg',
#  'dataset_Goldeen13.jpg',
#  'dataset_Goldeen2.jpg',
#  'dataset_Goldeen6.jpg',
#  'dataset_Goldeen17.jpg',
#  'dataset_Goldeen16.jpg',
#  'dataset_Goldeen7.jpg',
#  'dataset_Goldeen5.jpg',
#  'dataset_Goldeen28.jpg',
#  'dataset_Goldeen14.jpg',
#  'dataset_Goldeen15.jpg',
#  'dataset_Goldeen4.jpg',
#  'dataset_Venusaur17.jpg',
#  'dataset_Venusaur6.jpg',
#  'dataset_Venusaur7.jpg',
#  'dataset_Venusaur16.jpg',
#  'dataset_Venusaur14.jpg',
#  'dataset_Venusaur5.jpg',
#  'dataset_Venusaur4.jpg',
#  'dataset_Venusaur15.jpg',
#  'dataset_Venusaur11.jpg',
#  'dataset_Venusaur1.jpg',
#  'dataset_Venusaur10.jpg',
#  'dataset_Venusaur12.jpg',
#  'dataset_Venusaur3.jpg',
#  'dataset_Venusaur2.jpg',
#  'dataset_Venusaur13.jpg',
#  'dataset_Venusaur22.jpg',
#  'dataset_Venusaur23.jpg',
#  'dataset_Venusaur21.jpg',
#  'dataset_Venusaur20.jpg',
#  'dataset_Venusaur18.jpg',
#  'dataset_Venusaur9.jpg',
#  'dataset_Venusaur8.jpg',
#  'dataset_Venusaur19.jpg',
#  'dataset_Flareon3.jpg',
#  'dataset_Flareon11.jpg',
#  'dataset_Flareon10.jpg',
#  'dataset_Flareon2.jpg',
#  'dataset_Flareon12.jpg',
#  'dataset_Flareon13.jpg',
#  'dataset_Flareon1.jpg',
#  'dataset_Flareon5.jpg',
#  'dataset_Flareon17.jpg',
#  'dataset_Flareon16.jpg',
#  'dataset_Flareon4.jpg',
#  'dataset_Flareon6.jpg',
#  'dataset_Flareon14.jpg',
#  'dataset_Flareon28.jpg',
#  'dataset_Flareon29.jpg',
#  'dataset_Flareon15.jpg',
#  'dataset_Flareon7.jpg',
#  'dataset_Flareon18.jpg',
#  'dataset_Flareon30.jpg',
#  'dataset_Flareon24.jpg',
#  'dataset_Flareon25.jpg',
#  'dataset_Flareon31.jpg',
#  'dataset_Flareon19.jpg',
#  'dataset_Flareon9.jpg',
#  'dataset_Flareon27.jpg',
#  'dataset_Flareon26.jpg',
#  'dataset_Flareon8.jpg',
#  'dataset_Flareon22.jpg',
#  'dataset_Flareon23.jpg',
#  'dataset_Flareon21.jpg',
#  'dataset_Flareon20.jpg',
#  'dataset_Jigglypuff19.jpeg',
#  'dataset_Jigglypuff8.jpg',
#  'dataset_Jigglypuff9.jpg',
#  'dataset_Jigglypuff23.jpg',
#  'dataset_Jigglypuff22.jpg',
#  'dataset_Jigglypuff20.jpg',
#  'dataset_Jigglypuff21.jpg',
#  'dataset_Jigglypuff25.jpg',
#  'dataset_Jigglypuff31.jpg',
#  'dataset_Jigglypuff18.jpg',
#  'dataset_Jigglypuff30.jpg',
#  'dataset_Jigglypuff24.jpg',
#  'dataset_Jigglypuff26.jpg',
#  'dataset_Jigglypuff27.jpg',
#  'dataset_Jigglypuff16.jpg',
#  'dataset_Jigglypuff17.jpg',
#  'dataset_Jigglypuff29.jpg',
#  'dataset_Jigglypuff15.jpg',
#  'dataset_Jigglypuff14.jpg',
#  'dataset_Jigglypuff28.jpg',
#  'dataset_Jigglypuff10.jpg',
#  'dataset_Jigglypuff11.jpg',
#  'dataset_Jigglypuff13.jpg',
#  'dataset_Jigglypuff12.jpg',
#  'dataset_Jigglypuff4.jpg',
#  'dataset_Jigglypuff5.jpg',
#  'dataset_Jigglypuff7.jpg',
#  'dataset_Jigglypuff6.jpg',
#  'dataset_Jigglypuff2.jpg',
#  'dataset_Jigglypuff3.jpg',
#  'dataset_Jigglypuff1.jpg',
#  'dataset_Doduo6.jpg',
#  'dataset_Doduo20.jpg',
#  'dataset_Doduo21.jpg',
#  'dataset_Doduo7.jpg',
#  'dataset_Doduo5.jpg',
#  'dataset_Doduo23.jpg',
#  'dataset_Doduo22.jpg',
#  'dataset_Doduo4.jpg',
#  'dataset_Doduo26.jpg',
#  'dataset_Doduo27.jpg',
#  'dataset_Doduo1.jpg',
#  'dataset_Doduo3.jpg',
#  'dataset_Doduo19.jpg',
#  'dataset_Doduo25.jpg',
#  'dataset_Doduo24.jpg',
#  'dataset_Doduo18.jpg',
#  'dataset_Doduo2.jpg',
#  'dataset_Doduo15.jpg',
#  'dataset_Doduo28.jpg',
#  'dataset_Doduo14.jpg',
#  'dataset_Doduo16.jpg',
#  'dataset_Doduo17.jpg',
#  'dataset_Doduo9.jpg',
#  'dataset_Doduo13.jpg',
#  'dataset_Doduo12.jpg',
#  'dataset_Doduo8.jpg',
#  'dataset_Doduo10.jpg',
#  'dataset_Doduo11.jpg',
#  'dataset_Weedle19.jpg',
#  'dataset_Weedle25.jpg',
#  'dataset_Weedle31.jpg',
#  'dataset_Weedle30.jpg',
#  'dataset_Weedle24.jpg',
#  'dataset_Weedle18.jpg',
#  'dataset_Weedle32.jpg',
#  'dataset_Weedle26.jpg',
#  'dataset_Weedle27.jpg',
#  'dataset_Weedle33.jpg',
#  'dataset_Weedle37.jpg',
#  'dataset_Weedle23.jpg',
#  'dataset_Weedle22.jpg',
#  'dataset_Weedle36.jpg',
#  'dataset_Weedle20.jpg',
#  'dataset_Weedle34.jpg',
#  'dataset_Weedle35.jpg',
#  'dataset_Weedle21.jpg',
#  'dataset_Weedle9.jpg',
#  'dataset_Weedle8.jpg',
#  'dataset_Weedle6.jpg',
#  'dataset_Weedle7.jpg',
#  'dataset_Weedle5.jpg',
#  'dataset_Weedle4.jpg',
#  'dataset_Weedle1.jpg',
#  'dataset_Weedle3.jpg',
#  'dataset_Weedle2.jpg',
#  'dataset_Weedle38.jpg',
#  'dataset_Weedle10.jpg',
#  'dataset_Weedle11.jpg',
#  'dataset_Weedle13.jpg',
#  'dataset_Weedle12.jpg',
#  'dataset_Weedle16.jpg',
#  'dataset_Weedle17.jpg',
#  'dataset_Weedle15.jpg',
#  'dataset_Weedle29.jpg',
#  'dataset_Weedle28.jpg',
#  'dataset_Weedle14.jpg',
#  'dataset_Vileplume11.jpg',
#  'dataset_Vileplume10.jpg',
#  'dataset_Vileplume12.jpg',
#  'dataset_Vileplume13.jpg',
#  'dataset_Vileplume17.jpg',
#  'dataset_Vileplume16.jpg',
#  'dataset_Vileplume28.jpg',
#  'dataset_Vileplume14.jpg',
#  'dataset_Vileplume15.jpg',
#  'dataset_Vileplume29.jpg',
#  'dataset_Vileplume2.jpg',
#  'dataset_Vileplume3.jpg',
#  'dataset_Vileplume1.jpg',
#  'dataset_Vileplume4.jpg',
#  'dataset_Vileplume5.jpg',
#  'dataset_Vileplume7.jpg',
#  'dataset_Vileplume6.jpg',
#  'dataset_Vileplume8.jpg',
#  'dataset_Vileplume9.jpg',
#  'dataset_Vileplume30.jpg',
#  'dataset_Vileplume24.jpg',
#  'dataset_Vileplume18.jpg',
#  'dataset_Vileplume19.jpg',
#  'dataset_Vileplume25.jpg',
#  'dataset_Vileplume31.jpg',
#  'dataset_Vileplume27.jpg',
#  'dataset_Vileplume33.jpg',
#  'dataset_Vileplume32.jpg',
#  'dataset_Vileplume26.jpg',
#  'dataset_Vileplume22.jpg',
#  'dataset_Vileplume36.jpg',
#  'dataset_Vileplume23.jpg',
#  'dataset_Vileplume35.jpg',
#  'dataset_Vileplume21.jpg',
#  'dataset_Vileplume20.jpg',
#  'dataset_Vileplume34.jpg',
#  'dataset_Arcanine22.jpg',
#  'dataset_Arcanine36.jpg',
#  ...]

# %%
for label in class_labels:
    train_dir = os.path.join(path, "train", label)
    test_dir = os.path.join(path, "test", label)
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

# %%
train_images, test_images = train_test_split(image_list, test_size=0.2, random_state=42)

# %%
train_images
# Out:
# ['dataset_Arbok50.jpg',
#  'dataset_Charmander183.jpg',
#  'dataset_Charmander40.jpg',
#  'dataset_Primeape51.jpg',
#  'dataset_Dewgong60.jpg',
#  'dataset_Nidoqueen64.jpg',
#  'dataset_Mewtwo277.png',
#  'dataset_Venusaur20.jpg',
#  'dataset_Mankey51.jpg',
#  'dataset_Mankey67.jpg',
#  'dataset_Kingler37.jpg',
#  'dataset_Machamp40.jpg',
#  'dataset_Scyther46.jpg',
#  'dataset_Rattata34.jpg',
#  'dataset_Weedle25.jpg',
#  'dataset_Vulpix54.jpg',
#  'dataset_Charmander123.jpg',
#  'dataset_Lickitung53.jpg',
#  'dataset_Dewgong66.jpg',
#  'dataset_Venonat22.jpg',
#  'dataset_Sandshrew10.jpg',
#  'dataset_Mewtwo70.png',
#  'dataset_Mewtwo91.png',
#  'dataset_Weedle6.jpg',
#  'dataset_Meowth60.jpg',
#  'dataset_Ninetales63.jpg',
#  'dataset_Zapdos27.jpg',
#  'dataset_Charmeleon13.jpg',
#  'dataset_Omastar53.jpg',
#  'dataset_Pidgeot62.jpg',
#  'dataset_Chansey34.jpg',
#  'dataset_Machamp33.jpg',
#  'dataset_Metapod50.jpg',
#  'dataset_Charmander74.jpg',
#  'dataset_Chansey31.jpg',
#  'dataset_Metapod46.jpg',
#  'dataset_Persian35.jpg',
#  'dataset_Mew59.jpg',
#  'dataset_Primeape52.jpg',
#  'dataset_Nidoking45.jpg',
#  'dataset_Pikachu9.jpeg',
#  'dataset_Metapod18.jpg',
#  'dataset_Machamp31.jpg',
#  'dataset_Kingler4.jpg',
#  'dataset_Voltorb51.jpg',
#  'dataset_Magnemite29.jpg',
#  'dataset_Ivysaur27.jpg',
#  'dataset_Ninetales72.jpg',
#  'dataset_Charmander178.png',
#  'dataset_Moltres59.jpg',
#  'dataset_Flareon12.jpg',
#  'dataset_Gloom37.jpg',
#  'dataset_Hitmonchan36.jpg',
#  'dataset_Pikachu270.jpg',
#  'dataset_Snorlax49.jpg',
#  'dataset_Squirtle198.png',
#  'dataset_Horsea16.jpg',
#  'dataset_Flareon19.jpg',
#  'dataset_Diglett29.jpg',
#  'dataset_Charmander30.jpg',
#  'dataset_Psyduck118.jpg',
#  'dataset_Grimer53.jpg',
#  'dataset_Gastly45.jpg',
#  'dataset_Pikachu150.jpg',
#  'dataset_Muk20.jpg',
#  'dataset_Mewtwo198.jpg',
#  'dataset_Kangaskhan46.jpg',
#  'dataset_Eevee13.jpg',
#  'dataset_Seel13.jpg',
#  'dataset_Raticate58.jpg',
#  'dataset_Squirtle240.png',
#  'dataset_Psyduck83.jpg',
#  'dataset_Geodude44.jpg',
#  'dataset_Kabutops42.jpg',
#  'dataset_Lapras68.jpg',
#  'dataset_Charmander189.jpg',
#  'dataset_Krabby48.jpg',
#  'dataset_Pikachu45.png',
#  'dataset_Rhyhorn69.jpg',
#  'dataset_Raichu58.jpg',
#  'dataset_Jolteon25.jpg',
#  'dataset_Vaporeon25.jpg',
#  'dataset_Bulbasaur258.jpg',
#  'dataset_Snorlax48.jpg',
#  'dataset_Omanyte11.jpg',
#  'dataset_Ivysaur38.jpg',
#  'dataset_Exeggutor64.jpg',
#  'dataset_Bulbasaur220.jpg',
#  'dataset_Sandslash65.jpg',
#  'dataset_Haunter35.jpg',
#  'dataset_Wartortle34.jpg',
#  'dataset_Kabuto14.jpg',
#  'dataset_Exeggcute45.jpg',
#  'dataset_Victreebel49.jpg',
#  'dataset_Spearow39.jpg',
#  'dataset_Dratini81.jpg',
#  'dataset_Cubone48.jpg',
#  'dataset_Nidorina33.jpg',
#  'dataset_Ekans16.jpg',
#  'dataset_Shellder10.jpg',
#  'dataset_Dewgong45.jpg',
#  'dataset_Charmander247.jpg',
#  'dataset_Charmander33.png',
#  'dataset_Mewtwo258.png',
#  'dataset_Clefairy29.jpg',
#  'dataset_Dodrio63.jpg',
#  'dataset_Bulbasaur228.png',
#  'dataset_Squirtle214.jpg',
#  'dataset_Ekans28.jpg',
#  'dataset_Dragonite49.jpg',
#  'dataset_Meowth8.jpg',
#  'dataset_Mewtwo8.jpg',
#  'dataset_Bulbasaur265.jpg',
#  'dataset_Seadra18.jpg',
#  'dataset_Hypno11.jpg',
#  'dataset_Graveler3.jpg',
#  'dataset_Starmie49.jpg',
#  'dataset_Rhyhorn61.jpg',
#  'dataset_Alakazam1.jpg',
#  'dataset_Mewtwo23.jpg',
#  'dataset_Clefable6.jpg',
#  'dataset_Charmeleon12.jpg',
#  'dataset_Goldeen3.jpg',
#  'dataset_Pidgey57.jpg',
#  'dataset_Squirtle92.jpg',
#  'dataset_Poliwrath48.jpg',
#  'dataset_Zapdos2.jpg',
#  'dataset_Mewtwo203.png',
#  'dataset_Charmander146.jpg',
#  'dataset_Mewtwo234.jpg',
#  'dataset_Bulbasaur216.jpg',
#  'dataset_Clefairy30.jpg',
#  'dataset_Clefairy27.jpg',
#  'dataset_Squirtle229.jpg',
#  'dataset_Growlithe69.jpg',
#  'dataset_Ditto41.jpg',
#  'dataset_Cloyster38.jpg',
#  'dataset_Rhyhorn65.jpg',
#  'dataset_Jynx21.jpg',
#  'dataset_Dodrio26.jpg',
#  'dataset_Tauros49.jpg',
#  'dataset_Bulbasaur215.png',
#  'dataset_Metapod51.jpg',
#  'dataset_Psyduck147.jpg',
#  'dataset_Rapidash21.jpg',
#  'dataset_Hitmonlee38.jpg',
#  'dataset_Bulbasaur217.jpg',
#  'dataset_Hitmonchan60.jpg',
#  'dataset_Machoke13.jpg',
#  'dataset_Fearow105.jpg',
#  'dataset_Nidorino47.jpg',
#  'dataset_Charizard38.jpg',
#  'dataset_Paras35.jpg',
#  'dataset_Jolteon23.jpg',
#  'dataset_Graveler20.jpg',
#  'dataset_Flareon2.jpg',
#  'dataset_Omastar51.jpg',
#  'dataset_Abra10.jpg',
#  'dataset_Pikachu90.png',
#  'dataset_Bulbasaur44.jpg',
#  'dataset_Weezing34.jpg',
#  'dataset_Ivysaur52.jpg',
#  'dataset_Pikachu251.jpg',
#  'dataset_Machoke16.jpg',
#  'dataset_Hitmonlee13.jpg',
#  'dataset_Cloyster19.jpg',
#  'dataset_Ponyta23.jpg',
#  'dataset_Weezing44.jpg',
#  'dataset_Psyduck122.jpg',
#  'dataset_Bulbasaur169.png',
#  'dataset_Pinsir29.jpg',
#  'dataset_Voltorb25.jpg',
#  'dataset_Paras46.jpg',
#  'dataset_Tentacool36.jpg',
#  'dataset_Kadabra14.jpg',
#  'dataset_Pikachu156.jpg',
#  'dataset_Grimer31.jpg',
#  'dataset_Aerodactyl77.jpg',
#  'dataset_Mankey23.jpg',
#  'dataset_Goldeen26.jpg',
#  'dataset_Beedrill27.jpg',
#  'dataset_Mewtwo240.png',
#  'dataset_Venomoth47.jpg',
#  'dataset_Mewtwo173.jpg',
#  'dataset_Exeggutor61.jpg',
#  'dataset_Mewtwo113.png',
#  'dataset_Pidgey58.jpg',
#  'dataset_Mankey61.jpg',
#  'dataset_Slowpoke44.jpg',
#  'dataset_Mewtwo189.jpg',
#  'dataset_Vulpix49.jpg',
#  'dataset_Exeggutor13.jpg',
#  'dataset_Muk28.jpg',
#  'dataset_Kabutops51.jpg',
#  'dataset_Bulbasaur93.jpg',
#  'dataset_Pikachu141.jpg',
#  'dataset_Dewgong48.jpg',
#  'dataset_Sandslash51.jpg',
#  'dataset_Charmander235.jpg',
#  'dataset_Poliwag2.jpg',
#  'dataset_Lapras51.jpg',
#  'dataset_Krabby53.jpg',
#  'dataset_Chansey57.jpg',
#  'dataset_Charmander198.png',
#  'dataset_Koffing57.jpg',
#  'dataset_Squirtle127.jpg',
#  'dataset_Goldeen17.jpg',
#  'dataset_Flareon9.jpg',
#  'dataset_Venonat30.jpg',
#  'dataset_Mewtwo207.png',
#  'dataset_Butterfree62.jpg',
#  'dataset_Ponyta64.jpg',
#  'dataset_Rattata37.jpg',
#  'dataset_Jolteon14.jpg',
#  'dataset_Gastly46.jpg',
#  'dataset_Clefairy31.jpg',
#  'dataset_Charmeleon9.jpg',
#  'dataset_Rapidash47.jpg',
#  'dataset_Mewtwo288.jpg',
#  'dataset_Kadabra33.jpg',
#  'dataset_Rhyhorn14.jpg',
#  'dataset_Rhydon53.jpg',
#  'dataset_Pidgeot40.jpg',
#  'dataset_Pidgey41.jpg',
#  'dataset_Paras30.jpg',
#  'dataset_Pikachu245.jpeg',
#  'dataset_Gastly39.jpg',
#  'dataset_Caterpie27.jpg',
#  'dataset_Spearow17.jpg',
#  'dataset_Blastoise49.jpg',
#  'dataset_Fearow29.jpg',
#  'dataset_Gloom27.jpg',
#  'dataset_Muk2.jpg',
#  'dataset_Omastar40.jpg',
#  'dataset_Pikachu65.jpg',
#  'dataset_Pinsir23.jpg',
#  'dataset_Grimer44.jpg',
#  'dataset_Mewtwo201.png',
#  'dataset_Grimer30.jpg',
#  'dataset_Kakuna14.jpg',
#  'dataset_Magnemite37.jpg',
#  'dataset_Doduo20.jpg',
#  'dataset_Marowak18.jpg',
#  'dataset_Gengar17.jpg',
#  'dataset_Omanyte22.jpg',
#  'dataset_Mewtwo296.png',
#  'dataset_Exeggcute56.jpg',
#  'dataset_Flareon17.jpg',
#  'dataset_Bulbasaur247.jpg',
#  'dataset_Aerodactyl83.jpg',
#  'dataset_Tauros46.jpg',
#  'dataset_Sandslash49.jpg',
#  'dataset_Mewtwo63.png',
#  'dataset_Electabuzz41.jpg',
#  'dataset_Bulbasaur97.jpg',
#  'dataset_Zubat28.jpg',
#  'dataset_Growlithe56.jpg',
#  'dataset_Rhydon47.jpg',
#  'dataset_Nidoking64.jpg',
#  'dataset_Graveler25.jpg',
#  'dataset_Starmie11.jpg',
#  'dataset_Graveler30.jpg',
#  'dataset_Venusaur19.jpg',
#  'dataset_Mewtwo135.png',
#  'dataset_Kabuto26.jpg',
#  'dataset_Staryu36.jpg',
#  'dataset_Gastly3.jpg',
#  'dataset_Charmander279.png',
#  'dataset_Muk15.jpg',
#  'dataset_Fearow49.jpg',
#  'dataset_Seel38.jpg',
#  'dataset_Eevee20.jpg',
#  'dataset_Dodrio35.jpg',
#  'dataset_Dugtrio55.jpg',
#  'dataset_Pikachu48.jpg',
#  'dataset_Poliwag13.jpg',
#  'dataset_Beedrill33.jpg',
#  'dataset_Aerodactyl69.jpg',
#  'dataset_Exeggutor14.jpg',
#  'dataset_Horsea14.jpg',
#  'dataset_Pinsir32.jpg',
#  'dataset_Marowak25.jpg',
#  'dataset_Cubone16.jpg',
#  'dataset_Kabutops62.jpg',
#  'dataset_Vaporeon40.jpg',
#  'dataset_Sandslash13.jpg',
#  'dataset_Doduo21.jpg',
#  'dataset_Kingler5.jpg',
#  'dataset_Ekans48.jpg',
#  'dataset_Lapras15.jpg',
#  'dataset_Kabutops55.jpg',
#  'dataset_Onix51.jpg',
#  'dataset_Jynx55.jpg',
#  'dataset_Spearow29.jpg',
#  'dataset_Gastly42.jpg',
#  'dataset_Magmar15.jpg',
#  'dataset_Mewtwo92.png',
#  'dataset_Gengar39.jpg',
#  'dataset_Cloyster33.jpg',
#  'dataset_Hitmonchan21.jpg',
#  'dataset_Pidgey12.jpg',
#  'dataset_Charmander241.jpg',
#  'dataset_Venonat54.jpg',
#  'dataset_Ivysaur26.jpg',
#  'dataset_Staryu16.jpg',
#  'dataset_Dodrio65.jpg',
#  'dataset_Jynx9.jpeg',
#  'dataset_Dodrio54.jpg',
#  'dataset_Tauros61.jpg',
#  'dataset_Kabuto30.jpg',
#  'dataset_Magnemite36.jpg',
#  'dataset_Vaporeon32.jpg',
#  'dataset_Primeape53.jpeg',
#  'dataset_Omastar13.jpg',
#  'dataset_Charmander22.png',
#  'dataset_Dratini50.jpg',
#  'dataset_Pikachu130.jpg',
#  'dataset_Mewtwo249.png',
#  'dataset_Charmeleon24.jpg',
#  'dataset_Horsea43.jpg',
#  'dataset_Chansey24.jpg',
#  'dataset_Dratini54.jpg',
#  'dataset_Chansey21.jpg',
#  'dataset_Zubat26.jpg',
#  'dataset_Parasect12.jpg',
#  'dataset_Clefairy21.jpg',
#  'dataset_Kadabra11.jpg',
#  "dataset_Squirtle217.jpg')",
#  'dataset_Clefairy12.jpg',
#  'dataset_Psyduck137.jpg',
#  'dataset_Dewgong26.jpg',
#  'dataset_Squirtle279.png',
#  'dataset_Bulbasaur17.png',
#  'dataset_Snorlax68.jpg',
#  'dataset_Venusaur9.jpg',
#  'dataset_Farfetchd47.jpg',
#  'dataset_Onix25.jpg',
#  'dataset_Kangaskhan54.jpg',
#  'dataset_Paras37.jpg',
#  'dataset_Hypno4.jpg',
#  'dataset_Omanyte1.jpg',
#  'dataset_Venomoth65.jpg',
#  'dataset_Paras10.jpg',
#  'dataset_Blastoise27.jpg',
#  'dataset_Hitmonchan53.jpg',
#  'dataset_Mewtwo301.jpg',
#  'dataset_Squirtle62.jpg',
#  'dataset_Vulpix55.jpg',
#  'dataset_Arcanine23.jpg',
#  'dataset_Nidoqueen59.jpg',
#  'dataset_Parasect47.jpeg',
#  'dataset_Weezing62.jpg',
#  'dataset_Kabutops37.jpg',
#  'dataset_Mankey64.jpg',
#  'dataset_Weedle17.jpg',
#  'dataset_Haunter59.jpg',
#  'dataset_Nidorina25.jpg',
#  'dataset_Charmander10.jpg',
#  'dataset_Rattata39.jpg',
#  'dataset_Charizard30.jpg',
#  'dataset_Abra4.jpg',
#  'dataset_Primeape56.jpg',
#  'dataset_Grimer37.jpg',
#  'dataset_Rhydon52.jpg',
#  'dataset_Poliwrath59.jpg',
#  'dataset_Pikachu236.jpg',
#  'dataset_Fearow84.jpg',
#  'dataset_Pikachu276.png',
#  'dataset_Arcanine3.jpg',
#  'dataset_Meowth58.jpg',
#  'dataset_Kangaskhan17.jpg',
#  'dataset_Pikachu133.jpg',
#  'dataset_Weedle26.jpg',
#  'dataset_Mew55.jpg',
#  'dataset_Pidgeotto21.jpg',
#  'dataset_Machamp1.jpg',
#  'dataset_Kabuto33.jpg',
#  'dataset_Clefable8.jpg',
#  'dataset_Weedle36.jpg',
#  'dataset_Kingler16.jpg',
#  'dataset_Charmander215.jpg',
#  'dataset_Mewtwo190.png',
#  'dataset_Koffing44.jpg',
#  'dataset_Squirtle211.jpg',
#  'dataset_Charmander283.jpg',
#  'dataset_Magikarp7.jpg',
#  'dataset_Ninetales73.jpg',
#  'dataset_Tentacruel10.jpg',
#  'dataset_Charmander294.jpg',
#  'dataset_Electrode58.jpg',
#  'dataset_Mewtwo47.jpg',
#  'dataset_Chansey50.jpg',
#  'dataset_Rapidash25.jpg',
#  'dataset_Exeggutor65.jpg',
#  'dataset_Golem57.jpg',
#  'dataset_Tentacruel22.jpg',
#  'dataset_Dratini89.jpg',
#  'dataset_Fearow55.jpg',
#  'dataset_Pikachu228.png',
#  'dataset_Horsea62.jpg',
#  'dataset_Machamp4.jpg',
#  'dataset_Growlithe43.jpg',
#  'dataset_Exeggutor44.jpg',
#  'dataset_Charmander180.png',
#  'dataset_Fearow81.jpg',
#  'dataset_Mewtwo295.png',
#  'dataset_Pikachu44.png',
#  'dataset_Pikachu72.gif',
#  'dataset_Beedrill35.jpg',
#  'dataset_Omanyte8.jpg',
#  'dataset_Exeggutor49.jpg',
#  'dataset_Rhyhorn46.jpg',
#  'dataset_Dratini93.jpg',
#  'dataset_Dewgong22.jpg',
#  'dataset_Pidgeot21.jpg',
#  'dataset_Squirtle112.png',
#  'dataset_Squirtle181.jpg',
#  'dataset_Exeggutor46.jpg',
#  'dataset_Dragonite59.jpg',
#  'dataset_Ivysaur53.jpg',
#  'dataset_Arcanine31.jpg',
#  'dataset_Arcanine2.jpg',
#  'dataset_Tangela47.jpg',
#  'dataset_Venusaur21.jpg',
#  'dataset_Psyduck107.jpg',
#  'dataset_Squirtle143.png',
#  'dataset_Omanyte4.jpg',
#  'dataset_Mewtwo85.png',
#  'dataset_Bulbasaur259.jpg',
#  'dataset_Dewgong64.jpg',
#  'dataset_Ditto49.jpg',
#  'dataset_Spearow34.jpg',
#  'dataset_Machamp11.jpg',
#  'dataset_Mew36.jpg',
#  'dataset_Diglett12.jpg',
#  'dataset_Rapidash12.jpg',
#  'dataset_Poliwag35.jpg',
#  'dataset_Snorlax39.jpg',
#  'dataset_Meowth66.jpg',
#  'dataset_Kadabra19.jpg',
#  'dataset_Hitmonlee10.jpg',
#  'dataset_Squirtle78.png',
#  'dataset_Metapod35.jpg',
#  'dataset_Voltorb24.jpg',
#  'dataset_Seaking5.jpg',
#  'dataset_Poliwrath15.jpg',
#  'dataset_Ponyta40.jpg',
#  'dataset_Onix61.jpg',
#  'dataset_Bulbasaur83.jpg',
#  'dataset_Eevee5.jpg',
#  'dataset_Pidgeot63.jpg',
#  'dataset_Wartortle17.jpg',
#  'dataset_Haunter34.jpg',
#  'dataset_Goldeen6.jpg',
#  'dataset_Gastly25.jpg',
#  'dataset_Dragonite62.jpg',
#  'dataset_Kakuna41.jpg',
#  'dataset_Machamp39.jpg',
#  'dataset_Mewtwo268.jpg',
#  'dataset_Tentacool55.jpg',
#  'dataset_Moltres27.jpg',
#  'dataset_Geodude52.jpg',
#  'dataset_Mewtwo79.png',
#  'dataset_Vaporeon19.jpg',
#  'dataset_Machamp6.jpg',
#  'dataset_Blastoise42.jpg',
#  'dataset_Bulbasaur193.jpg',
#  'dataset_Victreebel47.jpg',
#  'dataset_Tentacruel25.jpg',
#  'dataset_Horsea29.jpg',
#  'dataset_Raticate51.jpg',
#  'dataset_Shellder12.jpg',
#  'dataset_Metapod47.jpg',
#  'dataset_Venonat48.jpg',
#  'dataset_Bulbasaur206.png',
#  'dataset_Exeggutor43.jpg',
#  'dataset_Exeggcute24.jpg',
#  'dataset_Spearow13.jpg',
#  'dataset_Starmie9.jpg',
#  'dataset_Nidorino16.jpg',
#  'dataset_Charmander228.png',
#  'dataset_Growlithe63.jpg',
#  'dataset_Raticate68.jpg',
#  'dataset_Shellder19.jpg',
#  'dataset_Weezing59.jpg',
#  'dataset_Drowzee28.jpg',
#  'dataset_Beedrill30.jpg',
#  'dataset_Mewtwo46.jpg',
#  'dataset_Oddish19.jpg',
#  'dataset_Charmander108.png',
#  'dataset_Gyarados15.jpg',
#  'dataset_Farfetchd56.jpg',
#  'dataset_Kadabra28.jpg',
#  'dataset_Voltorb42.jpg',
#  'dataset_Dratini23.jpg',
#  'dataset_Ekans25.jpg',
#  'dataset_Pidgeot32.jpg',
#  'dataset_Squirtle251.jpg',
#  'dataset_Charmander64.jpg',
#  'dataset_Mewtwo251.png',
#  'dataset_Pikachu205.png',
#  'dataset_Pinsir14.jpg',
#  'dataset_Kabutops46.jpg',
#  'dataset_Spearow32.jpg',
#  'dataset_Shellder37.jpg',
#  'dataset_Kangaskhan14.jpg',
#  'dataset_Squirtle49.jpg',
#  'dataset_Raticate42.jpg',
#  'dataset_Weezing37.jpg',
#  'dataset_Mewtwo266.jpg',
#  'dataset_Spearow26.jpg',
#  'dataset_Rapidash13.jpg',
#  'dataset_Fearow109.jpg',
#  'dataset_Poliwag36.jpg',
#  'dataset_Flareon20.jpg',
#  'dataset_Bulbasaur210.png',
#  'dataset_Primeape61.jpg',
#  'dataset_Bulbasaur48.png',
#  'dataset_Staryu58.jpg',
#  'dataset_Pikachu119.jpg',
#  'dataset_Electabuzz49.jpg',
#  'dataset_Haunter57.jpg',
#  'dataset_Muk51.jpg',
#  'dataset_Koffing18.jpg',
#  'dataset_Magnemite15.jpg',
#  'dataset_Muk23.jpg',
#  'dataset_Rapidash22.jpg',
#  'dataset_Kabutops26.jpg',
#  'dataset_Dratini98.jpg',
#  'dataset_Electabuzz48.jpg',
#  'dataset_Squirtle76.png',
#  'dataset_Omastar52.jpg',
#  'dataset_Gyarados7.jpg',
#  'dataset_Bulbasaur236.jpg',
#  'dataset_Zubat17.jpg',
#  'dataset_Pikachu218.jpg',
#  'dataset_Starmie37.jpg',
#  'dataset_Seel37.jpg',
#  'dataset_Nidoking67.jpg',
#  'dataset_Dodrio44.jpg',
#  'dataset_Scyther34.jpg',
#  'dataset_Golduck60.jpg',
#  'dataset_Rattata67.jpg',
#  'dataset_Tauros66.jpg',
#  'dataset_Charmander286.jpg',
#  'dataset_Blastoise57.jpg',
#  'dataset_Grimer34.jpg',
#  'dataset_Sandslash69.jpg',
#  'dataset_Pidgeot56.jpg',
#  'dataset_Fearow108.jpg',
#  'dataset_Vulpix41.jpg',
#  'dataset_Weedle7.jpg',
#  'dataset_Rhydon58.jpg',
#  'dataset_Nidorino10.jpg',
#  'dataset_Seel15.jpg',
#  'dataset_Squirtle205.jpg',
#  'dataset_Charmander124.jpg',
#  'dataset_Zubat24.jpg',
#  'dataset_Kadabra13.jpg',
#  'dataset_Slowpoke42.jpg',
#  'dataset_Muk39.jpg',
#  'dataset_Gengar47.jpg',
#  'dataset_Charmander139.png',
#  'dataset_Rhyhorn12.jpg',
#  'dataset_Golduck28.jpg',
#  'dataset_Mankey69.jpg',
#  'dataset_Mewtwo265.png',
#  'dataset_Bellsprout33.jpg',
#  'dataset_Seaking9.jpg',
#  'dataset_Growlithe51.jpg',
#  'dataset_Grimer45.jpg',
#  'dataset_Dragonair29.jpg',
#  'dataset_Mew56.jpg',
#  'dataset_Bulbasaur270.png',
#  'dataset_Bellsprout17.jpg',
#  'dataset_Charmander172.jpg',
#  'dataset_Magneton24.jpg',
#  'dataset_Ekans30.jpg',
#  'dataset_Flareon26.jpg',
#  'dataset_Kabutops43.jpg',
#  'dataset_Dugtrio26.jpg',
#  'dataset_Mewtwo180.jpg',
#  'dataset_Magneton15.jpg',
#  'dataset_Tangela49.jpg',
#  'dataset_Bulbasaur191.jpg',
#  'dataset_Clefairy7.jpg',
#  'dataset_Caterpie46.jpg',
#  'dataset_Diglett42.jpg',
#  'dataset_Golbat39.jpg',
#  'dataset_Slowpoke40.jpg',
#  'dataset_Mew61.jpg',
#  'dataset_Squirtle268.jpg',
#  'dataset_Nidorino45.jpg',
#  'dataset_Ponyta49.jpg',
#  'dataset_Bulbasaur229.jpg',
#  'dataset_Parasect44.jpg',
#  'dataset_Flareon5.jpg',
#  'dataset_Drowzee7.jpg',
#  'dataset_Spearow54.jpg',
#  'dataset_Bellsprout15.jpg',
#  'dataset_Growlithe35.jpg',
#  'dataset_Weedle30.jpg',
#  'dataset_Mewtwo236.jpg',
#  'dataset_Kadabra26.jpg',
#  'dataset_Marowak26.jpg',
#  'dataset_Gloom7.jpg',
#  'dataset_Onix47.jpg',
#  'dataset_Exeggutor9.jpg',
#  'dataset_Lapras67.jpg',
#  'dataset_Spearow41.jpg',
#  'dataset_Dewgong62.jpg',
#  'dataset_Kangaskhan40.jpg',
#  'dataset_Arcanine39.jpg',
#  'dataset_Mew57.jpg',
#  'dataset_Zubat19.jpg',
#  'dataset_Bulbasaur284.jpg',
#  'dataset_Mankey27.jpg',
#  'dataset_Seel4.jpg',
#  'dataset_Vaporeon60.jpg',
#  'dataset_Dewgong25.jpg',
#  'dataset_Dodrio60.jpg',
#  'dataset_Pidgeotto42.jpg',
#  'dataset_Squirtle153.jpg',
#  'dataset_Parasect28.jpg',
#  'dataset_Haunter20.jpg',
#  'dataset_Tentacool23.jpg',
#  'dataset_Caterpie36.jpg',
#  'dataset_Psyduck69.jpg',
#  'dataset_Metapod65.jpg',
#  'dataset_Ekans36.jpg',
#  'dataset_Machop14.jpg',
#  'dataset_Venomoth26.jpg',
#  'dataset_Bulbasaur213.jpg',
#  'dataset_Lapras9.jpg',
#  'dataset_Pikachu169.png',
#  'dataset_Hitmonlee46.jpg',
#  'dataset_Pikachu136.jpg',
#  'dataset_Mew43.jpg',
#  'dataset_Hypno9.jpg',
#  'dataset_Gyarados13.jpg',
#  'dataset_Charmander150.jpg',
#  'dataset_Omanyte21.jpg',
#  'dataset_Electrode59.jpg',
#  'dataset_Seaking4.jpg',
#  'dataset_Aerodactyl30.jpg',
#  'dataset_Hitmonlee52.jpg',
#  'dataset_Primeape11.jpg',
#  'dataset_Horsea44.jpg',
#  'dataset_Machop48.jpg',
#  'dataset_Exeggcute53.jpg',
#  'dataset_Moltres7.jpg',
#  'dataset_Oddish62.jpg',
#  'dataset_Articuno19.jpg',
#  'dataset_Slowpoke16.jpg',
#  'dataset_Chansey32.jpg',
#  'dataset_Psyduck115.jpg',
#  'dataset_Onix45.jpg',
#  'dataset_Nidoking68.jpg',
#  'dataset_Magneton2.jpg',
#  'dataset_Psyduck78.jpg',
#  'dataset_Psyduck119.jpg',
#  'dataset_Abra26.jpg',
#  'dataset_Ponyta25.jpg',
#  'dataset_Machop49.jpg',
#  'dataset_Weedle3.jpg',
#  'dataset_Mew27.jpg',
#  'dataset_Zapdos25.jpg',
#  'dataset_Jolteon10.jpg',
#  'dataset_Dodrio23.jpg',
#  'dataset_Pinsir34.jpg',
#  'dataset_Jolteon28.jpg',
#  'dataset_Pidgey72.jpg',
#  'dataset_Dugtrio54.jpg',
#  'dataset_Victreebel53.jpg',
#  'dataset_Ivysaur29.jpg',
#  'dataset_Slowpoke57.jpg',
#  'dataset_Rapidash45.jpg',
#  'dataset_Squirtle274.jpg',
#  'dataset_Dewgong43.jpg',
#  'dataset_Wartortle9.jpg',
#  'dataset_Wigglytuff41.jpg',
#  'dataset_Machop47.jpg',
#  'dataset_Farfetchd58.jpg',
#  'dataset_Blastoise51.jpg',
#  'dataset_Magikarp16.jpg',
#  'dataset_Fearow38.jpg',
#  'dataset_Arcanine40.jpg',
#  'dataset_Gengar55.jpg',
#  'dataset_Seadra50.jpg',
#  'dataset_Magmar57.jpg',
#  'dataset_Blastoise31.jpg',
#  'dataset_Mewtwo269.png',
#  'dataset_Mankey46.jpg',
#  'dataset_Ekans33.jpg',
#  'dataset_Charmander133.png',
#  'dataset_Pikachu139.png',
#  'dataset_Blastoise33.jpg',
#  'dataset_Dratini51.jpg',
#  'dataset_Magnemite17.jpg',
#  'dataset_Gengar51.jpg',
#  'dataset_Gyarados20.jpg',
#  'dataset_Zubat7.jpg',
#  'dataset_Electabuzz9.jpg',
#  'dataset_Paras48.jpg',
#  'dataset_Geodude24.jpg',
#  'dataset_Nidorino61.jpg',
#  'dataset_Jolteon29.jpg',
#  'dataset_Wartortle39.jpg',
#  'dataset_Slowpoke51.jpg',
#  'dataset_Graveler29.jpg',
#  'dataset_Slowpoke38.jpg',
#  'dataset_Dodrio31.jpg',
#  'dataset_Tentacool15.jpg',
#  'dataset_Charmander238.jpg',
#  'dataset_Tentacruel27.jpg',
#  'dataset_Magmar12.jpg',
#  'dataset_Magikarp4.jpg',
#  'dataset_Ponyta44.jpg',
#  'dataset_Krabby47.jpg',
#  'dataset_Haunter30.jpg',
#  'dataset_Diglett50.jpg',
#  'dataset_Pikachu191.jpg',
#  'dataset_Pidgeot45.jpg',
#  'dataset_Jolteon8.jpg',
#  'dataset_Gastly40.jpg',
#  'dataset_Cubone58.jpg',
#  'dataset_Squirtle250.jpg',
#  'dataset_Butterfree42.jpg',
#  'dataset_Omastar56.jpg',
#  'dataset_Moltres58.jpg',
#  'dataset_Pikachu239.jpg',
#  'dataset_Dragonair39.jpg',
#  'dataset_Mewtwo177.jpg',
#  'dataset_Fearow64.jpg',
#  'dataset_Psyduck82.jpg',
#  'dataset_Eevee7.jpg',
#  'dataset_Muk48.jpg',
#  'dataset_Vaporeon64.jpg',
#  'dataset_Mankey62.jpg',
#  'dataset_Bulbasaur148.png',
#  'dataset_Dugtrio63.jpg',
#  'dataset_Parasect15.jpg',
#  'dataset_Tentacruel7.jpg',
#  'dataset_Grimer21.jpg',
#  'dataset_Jigglypuff13.jpg',
#  'dataset_Charmander19.jpg',
#  'dataset_Gloom3.jpg',
#  'dataset_Golbat51.jpg',
#  'dataset_Arbok49.jpg',
#  'dataset_Rapidash17.jpg',
#  'dataset_Gyarados18.jpg',
#  'dataset_Moltres32.jpg',
#  'dataset_Vaporeon55.jpg',
#  'dataset_Victreebel54.jpg',
#  'dataset_Shellder26.jpg',
#  'dataset_Lickitung52.jpg',
#  'dataset_Sandslash67.jpg',
#  'dataset_Dugtrio40.jpg',
#  'dataset_Rhyhorn16.jpg',
#  'dataset_Articuno22.jpg',
#  'dataset_Mewtwo274.jpg',
#  'dataset_Vaporeon59.jpg',
#  'dataset_Blastoise56.jpg',
#  'dataset_Ivysaur44.jpg',
#  'dataset_Alakazam14.jpg',
#  'dataset_Kabuto29.jpg',
#  'dataset_Mewtwo162.png',
#  'dataset_Hitmonlee51.jpg',
#  'dataset_Rapidash18.jpg',
#  'dataset_Mewtwo160.jpg',
#  'dataset_Squirtle224.png',
#  'dataset_Hitmonchan27.jpg',
#  'dataset_Kingler27.jpg',
#  'dataset_Kabutops47.jpg',
#  'dataset_Wartortle29.jpg',
#  'dataset_Oddish56.jpg',
#  'dataset_Gyarados22.jpg',
#  'dataset_Kakuna17.jpg',
#  'dataset_Zubat10.jpg',
#  'dataset_Omastar50.jpg',
#  'dataset_Butterfree55.jpg',
#  'dataset_Ninetales66.jpg',
#  'dataset_Nidorino43.jpg',
#  'dataset_Sandshrew12.jpg',
#  'dataset_Machop45.jpg',
#  'dataset_Kingler26.jpg',
#  'dataset_Electabuzz44.jpg',
#  'dataset_Omastar11.jpg',
#  'dataset_Charmeleon11.jpg',
#  'dataset_Persian41.jpg',
#  'dataset_Gengar10.jpg',
#  'dataset_Jigglypuff5.jpg',
#  'dataset_Gastly41.jpg',
#  'dataset_Omastar12.svg',
#  'dataset_Tauros52.jpg',
#  'dataset_Blastoise44.jpg',
#  'dataset_Lickitung33.jpg',
#  'dataset_Charmander122.png',
#  'dataset_Marowak5.jpg',
#  'dataset_Arbok60.jpg',
#  'dataset_Arcanine36.jpg',
#  'dataset_Aerodactyl66.jpg',
#  'dataset_Scyther35.jpg',
#  'dataset_Beedrill51.jpg',
#  'dataset_Mankey18.jpg',
#  'dataset_Eevee15.jpg',
#  'dataset_Grimer51.jpg',
#  'dataset_MrMime44.jpg',
#  'dataset_Lickitung59.jpg',
#  'dataset_Pidgey59.jpg',
#  'dataset_Staryu15.jpg',
#  'dataset_Dewgong37.jpg',
#  'dataset_Squirtle188.jpg',
#  'dataset_Hitmonlee44.jpg',
#  'dataset_Snorlax57.jpg',
#  'dataset_Psyduck127.jpg',
#  'dataset_Venomoth66.jpg',
#  'dataset_Nidorino57.jpg',
#  'dataset_Metapod55.jpg',
#  'dataset_Caterpie33.jpg',
#  'dataset_Clefairy35.jpg',
#  'dataset_MrMime45.jpg',
#  'dataset_Bulbasaur180.jpg',
#  'dataset_Pidgey55.jpg',
#  'dataset_Golbat44.jpg',
#  'dataset_Kangaskhan53.jpg',
#  'dataset_Squirtle277.jpg',
#  'dataset_Aerodactyl70.jpg',
#  'dataset_Horsea1.jpg',
#  'dataset_Magneton22.svg',
#  'dataset_Pikachu231.jpg',
#  'dataset_Charmander116.png',
#  'dataset_Articuno21.jpg',
#  'dataset_Krabby61.jpg',
#  'dataset_Golbat58.jpg',
#  'dataset_Poliwrath62.jpg',
#  'dataset_Ditto31.jpg',
#  'dataset_Butterfree30.jpg',
#  'dataset_Ponyta21.jpg',
#  'dataset_Squirtle215.jpg',
#  'dataset_Charizard32.jpg',
#  'dataset_Eevee17.jpg',
#  'dataset_Venonat45.jpg',
#  'dataset_Shellder29.jpg',
#  'dataset_Bellsprout9.jpg',
#  'dataset_Omastar35.jpg',
#  'dataset_Pidgeotto40.jpg',
#  'dataset_Koffing33.jpg',
#  'dataset_Pikachu158.jpg',
#  'dataset_Farfetchd59.jpg',
#  'dataset_Lickitung32.jpg',
#  'dataset_Beedrill44.jpg',
#  'dataset_Mewtwo80.jpg',
#  'dataset_Sandshrew6.jpg',
#  'dataset_Tauros39.jpg',
#  'dataset_Bulbasaur219.jpg',
#  'dataset_Cloyster34.jpg',
#  'dataset_Gyarados12.jpg',
#  'dataset_Bellsprout10.jpg',
#  'dataset_Charmander212.png',
#  'dataset_Farfetchd45.jpg',
#  'dataset_Charmander153.jpg',
#  'dataset_Porygon49.jpg',
#  'dataset_Shellder2.jpg',
#  'dataset_Staryu37.jpg',
#  'dataset_Mewtwo241.jpg',
#  'dataset_Butterfree4.jpg',
#  'dataset_Squirtle93.jpg',
#  'dataset_Slowbro6.jpg',
#  'dataset_Mewtwo166.png',
#  'dataset_Cloyster27.jpg',
#  'dataset_Bellsprout7.jpg',
#  'dataset_Oddish22.jpg',
#  'dataset_Gengar28.jpg',
#  'dataset_Charmander60.jpg',
#  'dataset_Raichu7.jpg',
#  'dataset_Ditto19.jpg',
#  'dataset_Pikachu203.png',
#  'dataset_Mewtwo158.jpg',
#  'dataset_Mewtwo300.jpg',
#  'dataset_Squirtle235.jpg',
#  'dataset_Growlithe52.jpg',
#  'dataset_Dugtrio35.jpg',
#  'dataset_Zubat20.jpg',
#  'dataset_Weezing27.jpg',
#  'dataset_Venonat35.jpg',
#  'dataset_Drowzee5.jpg',
#  'dataset_Clefable16.jpg',
#  'dataset_Jolteon26.jpg',
#  'dataset_Diglett41.jpg',
#  'dataset_Articuno7.jpg',
#  'dataset_Jigglypuff23.jpg',
#  'dataset_Zubat9.jpg',
#  'dataset_Squirtle170.png',
#  'dataset_Vaporeon44.jpg',
#  'dataset_Pikachu143.jpg',
#  'dataset_Bulbasaur153.png',
#  'dataset_Rattata35.jpg',
#  'dataset_Flareon16.jpg',
#  'dataset_Pikachu157.jpg',
#  'dataset_Hitmonchan52.jpg',
#  'dataset_Kakuna64.jpg',
#  'dataset_Parasect14.jpg',
#  'dataset_Mewtwo1.png',
#  'dataset_Voltorb46.jpg',
#  'dataset_Jolteon24.jpg',
#  'dataset_Pikachu226.jpg',
#  'dataset_Aerodactyl87.jpg',
#  'dataset_Venomoth33.jpg',
#  'dataset_Pidgey61.jpg',
#  'dataset_Scyther54.jpg',
#  'dataset_Victreebel16.jpg',
#  'dataset_Bulbasaur266.png',
#  'dataset_Pinsir16.jpg',
#  'dataset_Eevee18.jpg',
#  'dataset_Aerodactyl71.jpg',
#  'dataset_Vaporeon34.jpg',
#  'dataset_Mewtwo145.png',
#  'dataset_Seel2.jpg',
#  'dataset_Seel11.jpg',
#  'dataset_Bulbasaur222.png',
#  'dataset_Vileplume23.jpg',
#  'dataset_Dewgong51.jpg',
#  'dataset_Mewtwo78.jpg',
#  'dataset_Ponyta41.jpg',
#  'dataset_Exeggutor60.jpg',
#  'dataset_Seel20.jpg',
#  'dataset_Weezing46.jpg',
#  'dataset_Psyduck139.jpg',
#  'dataset_Nidorina43.jpg',
#  'dataset_Ponyta35.jpg',
#  'dataset_Shellder28.jpg',
#  'dataset_Primeape63.jpg',
#  'dataset_Jolteon4.jpg',
#  'dataset_Dratini44.jpg',
#  'dataset_Omanyte29.jpg',
#  'dataset_Blastoise55.jpg',
#  'dataset_Alakazam6.jpeg',
#  'dataset_Cubone37.jpg',
#  'dataset_Poliwag27.jpg',
#  'dataset_Electabuzz23.jpg',
#  'dataset_Kabutops34.jpg',
#  'dataset_Starmie12.jpg',
#  'dataset_Seadra43.jpg',
#  'dataset_Horsea46.jpg',
#  'dataset_Machamp30.jpg',
#  'dataset_Muk40.jpg',
#  'dataset_Haunter25.jpg',
#  'dataset_Staryu28.jpg',
#  'dataset_Charmander217.png',
#  'dataset_Diglett48.jpg',
#  'dataset_Spearow25.jpg',
#  'dataset_Tangela29.jpg',
#  'dataset_Pikachu230.jpg',
#  'dataset_Wartortle16.jpg',
#  'dataset_Chansey20.jpg',
#  'dataset_Zubat1.jpg',
#  'dataset_Venomoth52.jpg',
#  'dataset_Diglett44.jpg',
#  'dataset_Kangaskhan48.jpg',
#  'dataset_Mewtwo259.jpg',
#  'dataset_Beedrill42.jpg',
#  'dataset_Koffing55.jpg',
#  'dataset_Rhydon46.jpg',
#  'dataset_Bulbasaur118.jpg',
#  'dataset_Persian53.jpg',
#  'dataset_Farfetchd63.jpg',
#  'dataset_Kakuna42.jpg',
#  'dataset_Pinsir2.jpg',
#  'dataset_Slowpoke52.jpg',
#  'dataset_Ditto23.jpg',
#  'dataset_Machop46.jpg',
#  'dataset_Omastar43.jpg',
#  'dataset_Graveler33.jpg',
#  'dataset_Pidgey43.jpg',
#  'dataset_Psyduck134.jpg',
#  'dataset_Raticate69.jpg',
#  'dataset_Grimer57.jpg',
#  'dataset_Mewtwo106.png',
#  'dataset_Arbok41.jpg',
#  'dataset_Charmander27.png',
#  'dataset_Haunter50.jpg',
#  'dataset_Graveler1.jpg',
#  'dataset_Gastly33.jpg',
#  'dataset_Machop51.jpg',
#  'dataset_Jigglypuff21.jpg',
#  'dataset_Mew33.jpg',
#  'dataset_Charmander202.png',
#  'dataset_Parasect48.jpg',
#  'dataset_Pikachu175.png',
#  'dataset_Staryu48.jpg',
#  'dataset_Omanyte2.jpg',
#  'dataset_Dodrio41.jpg',
#  'dataset_Squirtle149.png',
#  'dataset_Dodrio45.jpg',
#  'dataset_Raticate26.jpg',
#  'dataset_Charmander104.png',
#  'dataset_Clefable17.jpg',
#  'dataset_Poliwrath14.jpg',
#  'dataset_Mewtwo211.jpg',
#  ...]

# %%
for label in class_labels:
    label_dir = os.path.join(path, label)

    # move the train images into correct subfolder
    for image in train_images:
        src_path = os.path.join(label_dir, image)
        dst_path = os.path.join(train_dir, image)
        shutil.copyfile(src_path, dst_path)

    # move the test images into correct subfolder
    for image in test_images:
        src_path = os.path.join(label_dir, image)
        dst_path = os.path.join(test_dir, image)
        shutil.copyfile(src_path, dst_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 8
#       6     src_path = os.path.join(label_dir, image)
#       7     dst_path = os.path.join(train_dir, image)
# ----> 8     shutil.copyfile(src_path, dst_path)
#      10 # move the test images into correct subfolder
#      11 for image in test_images:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/middle-earth/lib/python3.8/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265         # macOS
#     266         if _HAS_FCOPYFILE:
#     267             try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/dataset/Zapdos/dataset_Arbok50.jpg'

# %%
class_labels
# Out:
# ['Zapdos',
#  'Kadabra',
#  'Omanyte',
#  'Shellder',
#  'Bellsprout',
#  'Eevee',
#  'Jolteon',
#  'Hypno',
#  'Seel',
#  'Zubat',
#  'Graveler',
#  'Magneton',
#  'Abra',
#  'Kingler',
#  'Alakazam',
#  'Clefable',
#  'Gyarados',
#  'Poliwag',
#  'Rapidash',
#  'test',
#  'Machamp',
#  'Pinsir',
#  'Muk',
#  'Seaking',
#  'Magikarp',
#  'Goldeen',
#  'Venusaur',
#  'Flareon',
#  'Jigglypuff',
#  'Doduo',
#  'Weedle',
#  'Vileplume',
#  'Arcanine',
#  'Tentacruel',
#  'Gloom',
#  'Charmeleon',
#  'Articuno',
#  'Sandshrew',
#  'Spearow',
#  'Marowak',
#  'Clefairy',
#  'Snorlax',
#  'Scyther',
#  'Primeape',
#  'Diglett',
#  'Onix',
#  'Mankey',
#  'Rattata',
#  'Voltorb',
#  'Gengar',
#  'Gastly',
#  'Cloyster',
#  'Weepinbell',
#  'Dragonair',
#  'Squirtle',
#  'Pikachu',
#  'Victreebel',
#  'Charmander',
#  'Staryu',
#  'Venonat',
#  'Vaporeon',
#  'Ivysaur',
#  'Krabby',
#  'Drowzee',
#  'Sandslash',
#  'Kangaskhan',
#  'Chansey',
#  'Butterfree',
#  'Starmie',
#  'Magmar',
#  'Beedrill',
#  'Ninetales',
#  'Magnemite',
#  'Metapod',
#  'Electrode',
#  'Raichu',
#  'Fearow',
#  'Mewtwo',
#  'Kabuto',
#  'Pidgeotto',
#  'Hitmonchan',
#  'Blastoise',
#  'Weezing',
#  'Golbat',
#  'Seadra',
#  'Rhyhorn',
#  'Moltres',
#  'Golduck',
#  'Kabutops',
#  'Aerodactyl',
#  'Haunter',
#  'Machop',
#  'Koffing',
#  'Pidgeot',
#  'Wigglytuff',
#  'Porygon',
#  'Vulpix',
#  'Dugtrio',
#  'Ditto',
#  'Raticate',
#  'Geodude',
#  'Tentacool',
#  'Horsea',
#  'Oddish',
#  'Machoke',
#  'Lapras',
#  'train',
#  'Poliwrath',
#  'Omastar',
#  'Slowpoke',
#  'Bulbasaur',
#  'Growlithe',
#  'Ponyta',
#  'Parasect',
#  'Dodrio',
#  'Meowth',
#  'Exeggutor',
#  '.ipynb_checkpoints',
#  'Persian',
#  'Psyduck',
#  'Tauros',
#  'Pidgey',
#  'Electabuzz',
#  'Dewgong',
#  'Wartortle',
#  'Nidoking',
#  'Grimer',
#  'Ekans',
#  'Caterpie',
#  'Tangela',
#  'Kakuna',
#  'Golem',
#  'Slowbro',
#  'MrMime',
#  'Jynx',
#  'Mew',
#  'Paras',
#  'Hitmonlee',
#  'Exeggcute',
#  'Arbok',
#  'Venomoth',
#  'Dratini',
#  'Cubone',
#  'Rhydon',
#  'Dragonite',
#  'Nidorino',
#  'Lickitung',
#  'Nidorina',
#  'Charizard',
#  'Poliwhirl',
#  'Nidoqueen',
#  'Farfetchd']

# %%
train_path = "data/dataset/train"
test_path = "data/dataset/test"

# %%
new_list = []
for image in image_list:
    if image in train_images:
        new_list.append(image)

# %%
new_list
# Out:
# ['dataset_Zapdos9.jpg',
#  'dataset_Zapdos8.jpg',
#  'dataset_Zapdos12.jpg',
#  'dataset_Zapdos13.jpg',
#  'dataset_Zapdos11.jpg',
#  'dataset_Zapdos10.jpg',
#  'dataset_Zapdos28.jpg',
#  'dataset_Zapdos14.jpg',
#  'dataset_Zapdos29.jpg',
#  'dataset_Zapdos17.jpg',
#  'dataset_Zapdos16.jpg',
#  'dataset_Zapdos27.jpg',
#  'dataset_Zapdos32.jpg',
#  'dataset_Zapdos24.jpg',
#  'dataset_Zapdos19.jpg',
#  'dataset_Zapdos25.jpg',
#  'dataset_Zapdos31.jpg',
#  'dataset_Zapdos21.jpg',
#  'dataset_Zapdos20.jpg',
#  'dataset_Zapdos23.jpg',
#  'dataset_Zapdos3.jpg',
#  'dataset_Zapdos2.jpg',
#  'dataset_Zapdos1.jpg',
#  'dataset_Zapdos5.jpg',
#  'dataset_Zapdos33.svg',
#  'dataset_Kadabra35.jpg',
#  'dataset_Kadabra21.jpg',
#  'dataset_Kadabra20.jpg',
#  'dataset_Kadabra22.jpg',
#  'dataset_Kadabra36.jpg',
#  'dataset_Kadabra37.jpg',
#  'dataset_Kadabra23.jpg',
#  'dataset_Kadabra27.jpg',
#  'dataset_Kadabra33.jpg',
#  'dataset_Kadabra26.jpg',
#  'dataset_Kadabra18.jpg',
#  'dataset_Kadabra24.jpg',
#  'dataset_Kadabra25.jpg',
#  'dataset_Kadabra19.jpg',
#  'dataset_Kadabra7.jpg',
#  'dataset_Kadabra6.jpg',
#  'dataset_Kadabra4.jpg',
#  'dataset_Kadabra5.jpg',
#  'dataset_Kadabra1.jpg',
#  'dataset_Kadabra2.jpg',
#  'dataset_Kadabra3.jpg',
#  'dataset_Kadabra8.jpg',
#  'dataset_Kadabra9.jpg',
#  'dataset_Kadabra14.jpg',
#  'dataset_Kadabra28.jpg',
#  'dataset_Kadabra15.jpg',
#  'dataset_Kadabra16.jpg',
#  'dataset_Kadabra12.jpg',
#  'dataset_Kadabra13.jpg',
#  'dataset_Kadabra11.jpg',
#  'dataset_Kadabra38.jpg',
#  'dataset_Omanyte11.jpg',
#  'dataset_Omanyte10.jpg',
#  'dataset_Omanyte8.jpg',
#  'dataset_Omanyte12.jpg',
#  'dataset_Omanyte13.jpg',
#  'dataset_Omanyte9.jpg',
#  'dataset_Omanyte14.jpg',
#  'dataset_Omanyte28.jpg',
#  'dataset_Omanyte29.jpg',
#  'dataset_Omanyte2.jpg',
#  'dataset_Omanyte18.jpg',
#  'dataset_Omanyte24.jpg',
#  'dataset_Omanyte25.jpg',
#  'dataset_Omanyte3.jpg',
#  'dataset_Omanyte1.jpg',
#  'dataset_Omanyte26.jpg',
#  'dataset_Omanyte22.jpg',
#  'dataset_Omanyte4.jpg',
#  'dataset_Omanyte5.jpg',
#  'dataset_Omanyte23.jpg',
#  'dataset_Omanyte21.jpg',
#  'dataset_Shellder2.jpg',
#  'dataset_Shellder16.jpg',
#  'dataset_Shellder17.jpg',
#  'dataset_Shellder29.jpg',
#  'dataset_Shellder28.jpg',
#  'dataset_Shellder4.jpg',
#  'dataset_Shellder10.jpg',
#  'dataset_Shellder38.jpg',
#  'dataset_Shellder39.jpg',
#  'dataset_Shellder11.jpg',
#  'dataset_Shellder5.jpg',
#  'dataset_Shellder7.jpg',
#  'dataset_Shellder13.jpg',
#  'dataset_Shellder12.jpg',
#  'dataset_Shellder37.jpg',
#  'dataset_Shellder23.jpg',
#  'dataset_Shellder36.jpg',
#  'dataset_Shellder8.jpg',
#  'dataset_Shellder20.jpg',
#  'dataset_Shellder34.jpg',
#  'dataset_Shellder35.jpg',
#  'dataset_Shellder21.jpg',
#  'dataset_Shellder9.jpg',
#  'dataset_Shellder31.jpg',
#  'dataset_Shellder19.jpg',
#  'dataset_Shellder30.jpg',
#  'dataset_Shellder24.jpg',
#  'dataset_Shellder32.jpg',
#  'dataset_Shellder26.jpg',
#  'dataset_Shellder27.jpg',
#  'dataset_Shellder33.jpg',
#  'dataset_Bellsprout30.jpg',
#  'dataset_Bellsprout4.jpg',
#  'dataset_Bellsprout5.jpg',
#  'dataset_Bellsprout19.jpg',
#  'dataset_Bellsprout31.jpg',
#  'dataset_Bellsprout33.jpg',
#  'dataset_Bellsprout7.jpg',
#  'dataset_Bellsprout6.jpg',
#  'dataset_Bellsprout26.jpg',
#  'dataset_Bellsprout32.jpg',
#  'dataset_Bellsprout3.jpg',
#  'dataset_Bellsprout23.jpg',
#  'dataset_Bellsprout21.jpg',
#  'dataset_Bellsprout35.jpg',
#  'dataset_Bellsprout1.jpg',
#  'dataset_Bellsprout34.jpg',
#  'dataset_Bellsprout20.jpg',
#  'dataset_Bellsprout11.jpg',
#  'dataset_Bellsprout10.jpg',
#  'dataset_Bellsprout17.jpg',
#  'dataset_Bellsprout16.jpg',
#  'dataset_Bellsprout28.jpg',
#  'dataset_Bellsprout14.jpg',
#  'dataset_Bellsprout8.jpg',
#  'dataset_Bellsprout9.jpg',
#  'dataset_Bellsprout15.jpg',
#  'dataset_Bellsprout29.jpg',
#  'dataset_Eevee9.jpg',
#  'dataset_Eevee18.jpg',
#  'dataset_Eevee23.jpg',
#  'dataset_Eevee20.jpg',
#  'dataset_Eevee10.jpg',
#  'dataset_Eevee11.jpg',
#  'dataset_Eevee13.jpg',
#  'dataset_Eevee12.jpg',
#  'dataset_Eevee16.jpg',
#  'dataset_Eevee17.jpg',
#  'dataset_Eevee15.jpg',
#  'dataset_Eevee14.jpg',
#  'dataset_Eevee4.jpg',
#  'dataset_Eevee5.jpg',
#  'dataset_Eevee7.jpg',
#  'dataset_Eevee6.jpg',
#  'dataset_Eevee1.jpg',
#  'dataset_Jolteon20.jpg',
#  'dataset_Jolteon21.jpg',
#  'dataset_Jolteon23.jpg',
#  'dataset_Jolteon22.jpg',
#  'dataset_Jolteon26.jpg',
#  'dataset_Jolteon27.jpg',
#  'dataset_Jolteon9.jpg',
#  'dataset_Jolteon31.jpg',
#  'dataset_Jolteon25.jpg',
#  'dataset_Jolteon24.jpg',
#  'dataset_Jolteon30.jpg',
#  'dataset_Jolteon18.jpg',
#  'dataset_Jolteon8.jpg',
#  'dataset_Jolteon5.jpg',
#  'dataset_Jolteon15.jpg',
#  'dataset_Jolteon29.jpg',
#  'dataset_Jolteon28.jpg',
#  'dataset_Jolteon14.jpg',
#  'dataset_Jolteon4.jpg',
#  'dataset_Jolteon16.jpg',
#  'dataset_Jolteon17.jpg',
#  'dataset_Jolteon7.jpg',
#  'dataset_Jolteon3.jpg',
#  'dataset_Jolteon13.jpg',
#  'dataset_Jolteon10.jpg',
#  'dataset_Jolteon1.jpg',
#  'dataset_Hypno1.jpg',
#  'dataset_Hypno2.jpg',
#  'dataset_Hypno3.jpg',
#  'dataset_Hypno7.jpg',
#  'dataset_Hypno6.jpg',
#  'dataset_Hypno4.jpg',
#  'dataset_Hypno23.jpg',
#  'dataset_Hypno21.jpg',
#  'dataset_Hypno20.jpg',
#  'dataset_Hypno24.jpg',
#  'dataset_Hypno19.jpg',
#  'dataset_Hypno16.jpg',
#  'dataset_Hypno14.jpg',
#  'dataset_Hypno11.jpg',
#  'dataset_Hypno10.jpg',
#  'dataset_Hypno13.jpg',
#  'dataset_Hypno8.jpg',
#  'dataset_Hypno9.jpg',
#  'dataset_Seel27.jpg',
#  'dataset_Seel32.jpg',
#  'dataset_Seel26.jpg',
#  'dataset_Seel18.jpg',
#  'dataset_Seel24.jpg',
#  'dataset_Seel25.jpg',
#  'dataset_Seel31.jpg',
#  'dataset_Seel19.jpg',
#  'dataset_Seel35.jpg',
#  'dataset_Seel21.jpg',
#  'dataset_Seel20.jpg',
#  'dataset_Seel34.jpg',
#  'dataset_Seel36.jpg',
#  'dataset_Seel37.jpg',
#  'dataset_Seel23.jpg',
#  'dataset_Seel1.jpg',
#  'dataset_Seel3.jpg',
#  'dataset_Seel2.jpg',
#  'dataset_Seel7.jpg',
#  'dataset_Seel5.jpg',
#  'dataset_Seel40.jpg',
#  'dataset_Seel4.jpg',
#  'dataset_Seel9.jpg',
#  'dataset_Seel8.jpg',
#  'dataset_Seel13.jpg',
#  'dataset_Seel39.jpg',
#  'dataset_Seel11.jpg',
#  'dataset_Seel38.jpg',
#  'dataset_Seel29.jpg',
#  'dataset_Seel15.jpg',
#  'dataset_Zubat24.jpg',
#  'dataset_Zubat18.jpg',
#  'dataset_Zubat19.jpg',
#  'dataset_Zubat25.jpg',
#  'dataset_Zubat8.jpg',
#  'dataset_Zubat26.jpg',
#  'dataset_Zubat9.jpg',
#  'dataset_Zubat22.jpg',
#  'dataset_Zubat20.jpg',
#  'dataset_Zubat2.jpg',
#  'dataset_Zubat11.jpg',
#  'dataset_Zubat10.jpg',
#  'dataset_Zubat3.jpg',
#  'dataset_Zubat1.jpg',
#  'dataset_Zubat13.jpg',
#  'dataset_Zubat4.jpg',
#  'dataset_Zubat17.jpg',
#  'dataset_Zubat5.jpg',
#  'dataset_Zubat7.jpg',
#  'dataset_Zubat28.jpg',
#  'dataset_Graveler33.jpg',
#  'dataset_Graveler27.jpg',
#  'dataset_Graveler26.jpg',
#  'dataset_Graveler32.jpg',
#  'dataset_Graveler18.jpg',
#  'dataset_Graveler24.jpg',
#  'dataset_Graveler30.jpg',
#  'dataset_Graveler25.jpg',
#  'dataset_Graveler19.jpg',
#  'dataset_Graveler35.jpg',
#  'dataset_Graveler34.jpg',
#  'dataset_Graveler20.jpg',
#  'dataset_Graveler22.jpg',
#  'dataset_Graveler23.jpg',
#  'dataset_Graveler37.jpg',
#  'dataset_Graveler7.jpg',
#  'dataset_Graveler6.jpg',
#  'dataset_Graveler5.jpg',
#  'dataset_Graveler1.jpg',
#  'dataset_Graveler3.jpg',
#  'dataset_Graveler9.jpg',
#  'dataset_Graveler12.jpg',
#  'dataset_Graveler11.jpg',
#  'dataset_Graveler10.jpg',
#  'dataset_Graveler38.jpg',
#  'dataset_Graveler14.jpg',
#  'dataset_Graveler28.jpg',
#  'dataset_Graveler29.jpg',
#  'dataset_Graveler15.jpg',
#  'dataset_Graveler17.jpg',
#  'dataset_Graveler16.jpg',
#  'dataset_Magneton1.jpg',
#  'dataset_Magneton3.jpg',
#  'dataset_Magneton2.jpg',
#  'dataset_Magneton22.svg',
#  'dataset_Magneton7.jpg',
#  'dataset_Magneton5.jpg',
#  'dataset_Magneton21.jpg',
#  'dataset_Magneton23.jpg',
#  'dataset_Magneton18.jpg',
#  'dataset_Magneton24.jpg',
#  'dataset_Magneton14.jpg',
#  'dataset_Magneton15.jpg',
#  'dataset_Magneton17.jpg',
#  'dataset_Magneton13.jpg',
#  'dataset_Magneton11.jpg',
#  'dataset_Magneton10.jpg',
#  'dataset_Magneton9.jpg',
#  'dataset_Magneton8.jpg',
#  'dataset_Abra10.jpg',
#  'dataset_Abra8.jpg',
#  'dataset_Abra9.jpg',
#  'dataset_Abra11.jpg',
#  'dataset_Abra13.jpg',
#  'dataset_Abra12.jpg',
#  'dataset_Abra17.jpg',
#  'dataset_Abra15.jpg',
#  'dataset_Abra14.jpeg',
#  'dataset_Abra19.jpg',
#  'dataset_Abra25.jpg',
#  'dataset_Abra1.jpg',
#  'dataset_Abra24.jpg',
#  'dataset_Abra26.jpg',
#  'dataset_Abra2.jpg',
#  'dataset_Abra3.jpg',
#  'dataset_Abra27.jpg',
#  'dataset_Abra23.jpg',
#  'dataset_Abra7.jpg',
#  'dataset_Abra22.jpg',
#  'dataset_Abra4.jpg',
#  'dataset_Abra5.jpg',
#  'dataset_Abra21.jpg',
#  'dataset_Kingler16.jpg',
#  'dataset_Kingler28.jpg',
#  'dataset_Kingler15.jpg',
#  'dataset_Kingler11.jpg',
#  'dataset_Kingler38.jpg',
#  'dataset_Kingler12.jpg',
#  'dataset_Kingler8.jpg',
#  'dataset_Kingler5.jpg',
#  'dataset_Kingler4.jpg',
#  'dataset_Kingler40.jpg',
#  'dataset_Kingler6.jpg',
#  'dataset_Kingler3.jpg',
#  'dataset_Kingler2.jpg',
#  'dataset_Kingler1.jpg',
#  'dataset_Kingler22.jpg',
#  'dataset_Kingler37.jpg',
#  'dataset_Kingler35.jpg',
#  'dataset_Kingler34.jpg',
#  'dataset_Kingler20.jpg',
#  'dataset_Kingler24.jpg',
#  'dataset_Kingler31.jpg',
#  'dataset_Kingler19.jpg',
#  'dataset_Kingler33.jpg',
#  'dataset_Kingler27.jpg',
#  'dataset_Kingler26.jpg',
#  'dataset_Alakazam7.jpg',
#  'dataset_Alakazam5.jpg',
#  'dataset_Alakazam4.jpg',
#  'dataset_Alakazam1.jpg',
#  'dataset_Alakazam3.jpg',
#  'dataset_Alakazam2.jpg',
#  'dataset_Alakazam17.jpg',
#  'dataset_Alakazam6.jpeg',
#  'dataset_Alakazam16.jpg',
#  'dataset_Alakazam14.jpg',
#  'dataset_Alakazam15.jpg',
#  'dataset_Alakazam10.jpg',
#  'dataset_Alakazam12.jpg',
#  'dataset_Alakazam19.jpg',
#  'dataset_Clefable3.jpg',
#  'dataset_Clefable1.jpg',
#  'dataset_Clefable5.jpg',
#  'dataset_Clefable6.jpg',
#  'dataset_Clefable24.jpg',
#  'dataset_Clefable18.jpg',
#  'dataset_Clefable19.jpg',
#  'dataset_Clefable25.jpg',
#  'dataset_Clefable27.jpg',
#  'dataset_Clefable23.jpg',
#  'dataset_Clefable21.jpg',
#  'dataset_Clefable20.jpg',
#  'dataset_Clefable11.jpg',
#  'dataset_Clefable12.jpg',
#  'dataset_Clefable13.jpg',
#  'dataset_Clefable17.jpg',
#  'dataset_Clefable16.jpg',
#  'dataset_Clefable14.jpg',
#  'dataset_Clefable8.jpg',
#  'dataset_Clefable9.jpg',
#  'dataset_Gyarados5.jpg',
#  'dataset_Gyarados6.jpg',
#  'dataset_Gyarados7.jpg',
#  'dataset_Gyarados3.jpg',
#  'dataset_Gyarados13.jpg',
#  'dataset_Gyarados12.jpg',
#  'dataset_Gyarados10.jpg',
#  'dataset_Gyarados11.jpg',
#  'dataset_Gyarados15.jpg',
#  'dataset_Gyarados14.jpg',
#  'dataset_Gyarados16.jpg',
#  'dataset_Gyarados17.jpg',
#  'dataset_Gyarados19.jpg',
#  'dataset_Gyarados18.jpg',
#  'dataset_Gyarados20.jpg',
#  'dataset_Gyarados22.jpg',
#  'dataset_Gyarados21.svg',
#  'dataset_Gyarados9.jpg',
#  'dataset_Gyarados8.jpg',
#  'dataset_Poliwag1.jpg',
#  'dataset_Poliwag14.jpg',
#  'dataset_Poliwag28.jpg',
#  'dataset_Poliwag29.jpg',
#  'dataset_Poliwag15.jpg',
#  'dataset_Poliwag2.jpg',
#  'dataset_Poliwag17.jpg',
#  'dataset_Poliwag16.jpg',
#  'dataset_Poliwag7.jpg',
#  'dataset_Poliwag12.jpg',
#  'dataset_Poliwag13.jpg',
#  'dataset_Poliwag4.jpg',
#  'dataset_Poliwag39.jpg',
#  'dataset_Poliwag10.jpg',
#  'dataset_Poliwag38.jpg',
#  'dataset_Poliwag5.jpg',
#  'dataset_Poliwag8.jpg',
#  'dataset_Poliwag35.jpg',
#  'dataset_Poliwag20.jpg',
#  'dataset_Poliwag34.jpg',
#  'dataset_Poliwag9.jpg',
#  'dataset_Poliwag36.jpg',
#  'dataset_Poliwag23.jpg',
#  'dataset_Poliwag27.jpg',
#  'dataset_Poliwag33.jpg',
#  'dataset_Poliwag32.jpg',
#  'dataset_Poliwag18.jpg',
#  'dataset_Poliwag30.jpg',
#  'dataset_Poliwag24.jpg',
#  'dataset_Poliwag25.jpg',
#  'dataset_Poliwag31.jpg',
#  'dataset_Rapidash11.jpg',
#  'dataset_Rapidash39.jpg',
#  'dataset_Rapidash12.jpg',
#  'dataset_Rapidash13.jpg',
#  'dataset_Rapidash17.jpg',
#  'dataset_Rapidash16.jpg',
#  'dataset_Rapidash28.jpg',
#  'dataset_Rapidash14.jpg',
#  'dataset_Rapidash15.jpg',
#  'dataset_Rapidash29.jpg',
#  'dataset_Rapidash7.jpg',
#  'dataset_Rapidash6.jpg',
#  'dataset_Rapidash1.jpg',
#  'dataset_Rapidash48.jpg',
#  'dataset_Rapidash2.jpg',
#  'dataset_Rapidash3.jpg',
#  'dataset_Rapidash47.jpg',
#  'dataset_Rapidash46.jpg',
#  'dataset_Rapidash45.jpg',
#  'dataset_Rapidash41.jpg',
#  'dataset_Rapidash40.jpg',
#  'dataset_Rapidash42.jpg',
#  'dataset_Rapidash43.jpg',
#  'dataset_Rapidash30.jpg',
#  'dataset_Rapidash24.jpg',
#  'dataset_Rapidash18.jpg',
#  'dataset_Rapidash19.jpg',
#  'dataset_Rapidash25.jpg',
#  'dataset_Rapidash31.jpg',
#  'dataset_Rapidash32.jpg',
#  'dataset_Rapidash26.jpg',
#  'dataset_Rapidash22.jpg',
#  'dataset_Rapidash36.jpg',
#  'dataset_Rapidash35.jpg',
#  'dataset_Rapidash21.jpg',
#  'dataset_Rapidash20.jpg',
#  'dataset_Rapidash34.jpg',
#  'dataset_Machamp14.jpg',
#  'dataset_Machamp9.jpg',
#  'dataset_Machamp29.jpg',
#  'dataset_Machamp15.jpg',
#  'dataset_Machamp17.jpg',
#  'dataset_Machamp16.jpg',
#  'dataset_Machamp12.jpg',
#  'dataset_Machamp13.jpg',
#  'dataset_Machamp39.jpg',
#  'dataset_Machamp11.jpg',
#  'dataset_Machamp38.jpg',
#  'dataset_Machamp40.jpg',
#  'dataset_Machamp44.jpg',
#  'dataset_Machamp45.jpg',
#  'dataset_Machamp35.svg',
#  'dataset_Machamp46.jpg',
#  'dataset_Machamp21.jpg',
#  'dataset_Machamp1.jpg',
#  'dataset_Machamp34.jpg',
#  'dataset_Machamp20.jpg',
#  'dataset_Machamp36.jpg',
#  'dataset_Machamp22.jpg',
#  'dataset_Machamp3.jpg',
#  'dataset_Machamp2.jpg',
#  'dataset_Machamp23.jpg',
#  'dataset_Machamp37.jpg',
#  'dataset_Machamp33.jpg',
#  'dataset_Machamp27.jpg',
#  'dataset_Machamp6.jpg',
#  'dataset_Machamp7.jpg',
#  'dataset_Machamp26.jpg',
#  'dataset_Machamp32.jpg',
#  'dataset_Machamp18.jpg',
#  'dataset_Machamp24.jpg',
#  'dataset_Machamp30.jpg',
#  'dataset_Machamp5.jpg',
#  'dataset_Machamp4.jpg',
#  'dataset_Machamp31.jpg',
#  'dataset_Pinsir8.jpg',
#  'dataset_Pinsir32.jpg',
#  'dataset_Pinsir26.jpg',
#  'dataset_Pinsir27.jpg',
#  'dataset_Pinsir33.jpg',
#  'dataset_Pinsir19.jpg',
#  'dataset_Pinsir25.jpg',
#  'dataset_Pinsir31.jpg',
#  'dataset_Pinsir30.jpg',
#  'dataset_Pinsir24.jpg',
#  'dataset_Pinsir18.jpg',
#  'dataset_Pinsir20.jpg',
#  'dataset_Pinsir34.jpg',
#  'dataset_Pinsir21.jpg',
#  'dataset_Pinsir23.jpg',
#  'dataset_Pinsir22.jpg',
#  'dataset_Pinsir13.jpg',
#  'dataset_Pinsir12.jpg',
#  'dataset_Pinsir10.jpg',
#  'dataset_Pinsir11.jpg',
#  'dataset_Pinsir29.jpg',
#  'dataset_Pinsir28.jpg',
#  'dataset_Pinsir14.jpg',
#  'dataset_Pinsir16.jpg',
#  'dataset_Pinsir1.jpg',
#  'dataset_Pinsir2.jpg',
#  'dataset_Pinsir6.jpg',
#  'dataset_Pinsir7.jpg',
#  'dataset_Pinsir5.jpg',
#  'dataset_Pinsir4.jpg',
#  'dataset_Muk37.jpg',
#  'dataset_Muk23.jpg',
#  'dataset_Muk36.jpg',
#  'dataset_Muk20.jpg',
#  'dataset_Muk34.jpg',
#  'dataset_Muk35.jpg',
#  'dataset_Muk25.jpg',
#  'dataset_Muk31.jpg',
#  'dataset_Muk19.jpg',
#  'dataset_Muk18.jpg',
#  'dataset_Muk24.jpg',
#  'dataset_Muk32.jpg',
#  'dataset_Muk26.jpg',
#  'dataset_Muk33.jpg',
#  'dataset_Muk40.jpg',
#  'dataset_Muk5.jpg',
#  'dataset_Muk6.jpg',
#  'dataset_Muk7.jpg',
#  'dataset_Muk42.jpg',
#  'dataset_Muk46.jpg',
#  'dataset_Muk3.jpg',
#  'dataset_Muk2.jpg',
#  'dataset_Muk47.jpg',
#  'dataset_Muk51.jpg',
#  'dataset_Muk1.jpg',
#  'dataset_Muk44.jpg',
#  'dataset_Muk48.jpg',
#  'dataset_Muk9.jpg',
#  'dataset_Muk8.jpg',
#  'dataset_Muk16.jpg',
#  'dataset_Muk17.jpg',
#  'dataset_Muk15.jpg',
#  'dataset_Muk14.jpg',
#  'dataset_Muk28.jpg',
#  'dataset_Muk38.jpg',
#  'dataset_Muk39.jpg',
#  'dataset_Muk13.jpg',
#  'dataset_Seaking13.jpg',
#  'dataset_Seaking7.jpg',
#  'dataset_Seaking6.jpg',
#  'dataset_Seaking10.jpg',
#  'dataset_Seaking4.jpg',
#  'dataset_Seaking5.jpg',
#  'dataset_Seaking14.jpg',
#  'dataset_Seaking16.jpg',
#  'dataset_Seaking17.jpg',
#  'dataset_Seaking18.jpg',
#  'dataset_Seaking9.jpg',
#  'dataset_Magikarp7.jpg',
#  'dataset_Magikarp6.jpg',
#  'dataset_Magikarp4.jpg',
#  'dataset_Magikarp5.jpg',
#  'dataset_Magikarp1.jpg',
#  'dataset_Magikarp2.jpg',
#  'dataset_Magikarp24.jpg',
#  'dataset_Magikarp18.jpg',
#  'dataset_Magikarp26.jpg',
#  'dataset_Magikarp23.jpg',
#  'dataset_Magikarp22.jpg',
#  'dataset_Magikarp20.jpg',
#  'dataset_Magikarp21.jpg',
#  'dataset_Magikarp10.jpg',
#  'dataset_Magikarp11.jpg',
#  'dataset_Magikarp13.jpg',
#  'dataset_Magikarp16.jpg',
#  'dataset_Magikarp17.jpg',
#  'dataset_Magikarp15.jpg',
#  'dataset_Magikarp14.jpg',
#  'dataset_Magikarp8.jpg',
#  'dataset_Magikarp9.jpg',
#  'dataset_Goldeen24.jpg',
#  'dataset_Goldeen18.jpg',
#  'dataset_Goldeen19.jpg',
#  'dataset_Goldeen8.jpg',
#  'dataset_Goldeen26.jpg',
#  'dataset_Goldeen22.jpg',
#  'dataset_Goldeen23.jpg',
#  'dataset_Goldeen21.jpg',
#  'dataset_Goldeen11.jpg',
#  'dataset_Goldeen10.jpg',
#  'dataset_Goldeen1.jpg',
#  'dataset_Goldeen3.jpg',
#  'dataset_Goldeen12.jpg',
#  'dataset_Goldeen2.jpg',
#  'dataset_Goldeen6.jpg',
#  'dataset_Goldeen17.jpg',
#  'dataset_Goldeen16.jpg',
#  'dataset_Goldeen5.jpg',
#  'dataset_Venusaur7.jpg',
#  'dataset_Venusaur16.jpg',
#  'dataset_Venusaur14.jpg',
#  'dataset_Venusaur5.jpg',
#  'dataset_Venusaur4.jpg',
#  'dataset_Venusaur15.jpg',
#  'dataset_Venusaur11.jpg',
#  'dataset_Venusaur1.jpg',
#  'dataset_Venusaur10.jpg',
#  'dataset_Venusaur12.jpg',
#  'dataset_Venusaur3.jpg',
#  'dataset_Venusaur2.jpg',
#  'dataset_Venusaur13.jpg',
#  'dataset_Venusaur22.jpg',
#  'dataset_Venusaur23.jpg',
#  'dataset_Venusaur21.jpg',
#  'dataset_Venusaur20.jpg',
#  'dataset_Venusaur18.jpg',
#  'dataset_Venusaur9.jpg',
#  'dataset_Venusaur8.jpg',
#  'dataset_Venusaur19.jpg',
#  'dataset_Flareon3.jpg',
#  'dataset_Flareon11.jpg',
#  'dataset_Flareon10.jpg',
#  'dataset_Flareon2.jpg',
#  'dataset_Flareon12.jpg',
#  'dataset_Flareon13.jpg',
#  'dataset_Flareon1.jpg',
#  'dataset_Flareon5.jpg',
#  'dataset_Flareon17.jpg',
#  'dataset_Flareon16.jpg',
#  'dataset_Flareon4.jpg',
#  'dataset_Flareon6.jpg',
#  'dataset_Flareon14.jpg',
#  'dataset_Flareon28.jpg',
#  'dataset_Flareon15.jpg',
#  'dataset_Flareon7.jpg',
#  'dataset_Flareon18.jpg',
#  'dataset_Flareon30.jpg',
#  'dataset_Flareon24.jpg',
#  'dataset_Flareon25.jpg',
#  'dataset_Flareon31.jpg',
#  'dataset_Flareon19.jpg',
#  'dataset_Flareon9.jpg',
#  'dataset_Flareon27.jpg',
#  'dataset_Flareon26.jpg',
#  'dataset_Flareon8.jpg',
#  'dataset_Flareon23.jpg',
#  'dataset_Flareon21.jpg',
#  'dataset_Flareon20.jpg',
#  'dataset_Jigglypuff8.jpg',
#  'dataset_Jigglypuff9.jpg',
#  'dataset_Jigglypuff23.jpg',
#  'dataset_Jigglypuff22.jpg',
#  'dataset_Jigglypuff20.jpg',
#  'dataset_Jigglypuff21.jpg',
#  'dataset_Jigglypuff25.jpg',
#  'dataset_Jigglypuff31.jpg',
#  'dataset_Jigglypuff18.jpg',
#  'dataset_Jigglypuff30.jpg',
#  'dataset_Jigglypuff24.jpg',
#  'dataset_Jigglypuff27.jpg',
#  'dataset_Jigglypuff17.jpg',
#  'dataset_Jigglypuff15.jpg',
#  'dataset_Jigglypuff14.jpg',
#  'dataset_Jigglypuff28.jpg',
#  'dataset_Jigglypuff10.jpg',
#  'dataset_Jigglypuff11.jpg',
#  'dataset_Jigglypuff13.jpg',
#  'dataset_Jigglypuff12.jpg',
#  'dataset_Jigglypuff5.jpg',
#  'dataset_Jigglypuff7.jpg',
#  'dataset_Jigglypuff6.jpg',
#  'dataset_Jigglypuff3.jpg',
#  'dataset_Jigglypuff1.jpg',
#  'dataset_Doduo20.jpg',
#  'dataset_Doduo21.jpg',
#  'dataset_Doduo7.jpg',
#  'dataset_Doduo5.jpg',
#  'dataset_Doduo23.jpg',
#  'dataset_Doduo22.jpg',
#  'dataset_Doduo26.jpg',
#  'dataset_Doduo27.jpg',
#  'dataset_Doduo1.jpg',
#  'dataset_Doduo19.jpg',
#  'dataset_Doduo25.jpg',
#  'dataset_Doduo24.jpg',
#  'dataset_Doduo2.jpg',
#  'dataset_Doduo15.jpg',
#  'dataset_Doduo28.jpg',
#  'dataset_Doduo16.jpg',
#  'dataset_Doduo17.jpg',
#  'dataset_Doduo9.jpg',
#  'dataset_Doduo13.jpg',
#  'dataset_Doduo12.jpg',
#  'dataset_Doduo8.jpg',
#  'dataset_Doduo10.jpg',
#  'dataset_Doduo11.jpg',
#  'dataset_Weedle19.jpg',
#  'dataset_Weedle25.jpg',
#  'dataset_Weedle30.jpg',
#  'dataset_Weedle24.jpg',
#  'dataset_Weedle18.jpg',
#  'dataset_Weedle32.jpg',
#  'dataset_Weedle26.jpg',
#  'dataset_Weedle33.jpg',
#  'dataset_Weedle37.jpg',
#  'dataset_Weedle23.jpg',
#  'dataset_Weedle22.jpg',
#  'dataset_Weedle36.jpg',
#  'dataset_Weedle20.jpg',
#  'dataset_Weedle34.jpg',
#  'dataset_Weedle35.jpg',
#  'dataset_Weedle21.jpg',
#  'dataset_Weedle9.jpg',
#  'dataset_Weedle8.jpg',
#  'dataset_Weedle6.jpg',
#  'dataset_Weedle7.jpg',
#  'dataset_Weedle5.jpg',
#  'dataset_Weedle4.jpg',
#  'dataset_Weedle1.jpg',
#  'dataset_Weedle3.jpg',
#  'dataset_Weedle2.jpg',
#  'dataset_Weedle38.jpg',
#  'dataset_Weedle11.jpg',
#  'dataset_Weedle13.jpg',
#  'dataset_Weedle12.jpg',
#  'dataset_Weedle16.jpg',
#  'dataset_Weedle17.jpg',
#  'dataset_Weedle15.jpg',
#  'dataset_Weedle29.jpg',
#  'dataset_Weedle14.jpg',
#  'dataset_Vileplume11.jpg',
#  'dataset_Vileplume10.jpg',
#  'dataset_Vileplume13.jpg',
#  'dataset_Vileplume17.jpg',
#  'dataset_Vileplume16.jpg',
#  'dataset_Vileplume28.jpg',
#  'dataset_Vileplume15.jpg',
#  'dataset_Vileplume29.jpg',
#  'dataset_Vileplume2.jpg',
#  'dataset_Vileplume3.jpg',
#  'dataset_Vileplume1.jpg',
#  'dataset_Vileplume4.jpg',
#  'dataset_Vileplume5.jpg',
#  'dataset_Vileplume8.jpg',
#  'dataset_Vileplume9.jpg',
#  'dataset_Vileplume30.jpg',
#  'dataset_Vileplume24.jpg',
#  'dataset_Vileplume18.jpg',
#  'dataset_Vileplume19.jpg',
#  'dataset_Vileplume25.jpg',
#  'dataset_Vileplume31.jpg',
#  'dataset_Vileplume27.jpg',
#  'dataset_Vileplume33.jpg',
#  'dataset_Vileplume32.jpg',
#  'dataset_Vileplume26.jpg',
#  'dataset_Vileplume22.jpg',
#  'dataset_Vileplume36.jpg',
#  'dataset_Vileplume23.jpg',
#  'dataset_Vileplume21.jpg',
#  'dataset_Vileplume34.jpg',
#  'dataset_Arcanine22.jpg',
#  'dataset_Arcanine36.jpg',
#  'dataset_Arcanine37.jpg',
#  'dataset_Arcanine23.jpg',
#  'dataset_Arcanine21.jpg',
#  'dataset_Arcanine20.jpg',
#  'dataset_Arcanine34.jpg',
#  'dataset_Arcanine18.jpg',
#  'dataset_Arcanine30.jpg',
#  'dataset_Arcanine24.jpg',
#  'dataset_Arcanine25.jpg',
#  'dataset_Arcanine31.jpg',
#  'dataset_Arcanine19.jpg',
#  'dataset_Arcanine8.jpg',
#  'dataset_Arcanine27.jpg',
#  'dataset_Arcanine33.jpg',
#  'dataset_Arcanine32.jpg',
#  'dataset_Arcanine26.jpg',
#  'dataset_Arcanine9.jpg',
#  'dataset_Arcanine40.jpg',
#  'dataset_Arcanine4.jpg',
#  'dataset_Arcanine16.jpg',
#  'dataset_Arcanine7.jpg',
#  'dataset_Arcanine29.jpg',
#  'dataset_Arcanine6.jpg',
#  'dataset_Arcanine2.jpg',
#  'dataset_Arcanine39.jpg',
#  'dataset_Arcanine11.jpg',
#  'dataset_Arcanine3.jpg',
#  'dataset_Arcanine1.jpg',
#  'dataset_Arcanine12.jpg',
#  'dataset_Arcanine13.jpg',
#  'dataset_Tentacruel11.jpg',
#  'dataset_Tentacruel10.jpg',
#  'dataset_Tentacruel14.jpg',
#  'dataset_Tentacruel29.jpg',
#  'dataset_Tentacruel16.jpg',
#  'dataset_Tentacruel4.jpg',
#  'dataset_Tentacruel33.jpg',
#  'dataset_Tentacruel27.jpg',
#  'dataset_Tentacruel26.jpg',
#  'dataset_Tentacruel32.jpg',
#  'dataset_Tentacruel7.jpg',
#  'dataset_Tentacruel18.jpg',
#  'dataset_Tentacruel19.jpg',
#  'dataset_Tentacruel31.jpg',
#  'dataset_Tentacruel25.jpg',
#  'dataset_Tentacruel6.jpg',
#  'dataset_Tentacruel2.jpg',
#  'dataset_Tentacruel21.jpg',
#  'dataset_Tentacruel20.jpg',
#  'dataset_Tentacruel3.jpg',
#  'dataset_Tentacruel1.jpg',
#  'dataset_Tentacruel22.jpg',
#  'dataset_Tentacruel23.jpg',
#  'dataset_Tentacruel24.svg',
#  'dataset_Gloom27.jpg',
#  'dataset_Gloom33.jpg',
#  'dataset_Gloom30.jpg',
#  'dataset_Gloom24.jpg',
#  'dataset_Gloom25.jpg',
#  'dataset_Gloom31.jpg',
#  'dataset_Gloom19.jpg',
#  'dataset_Gloom35.jpg',
#  'dataset_Gloom21.jpg',
#  'dataset_Gloom20.jpg',
#  'dataset_Gloom22.jpg',
#  'dataset_Gloom37.jpg',
#  'dataset_Gloom23.jpg',
#  'dataset_Gloom8.jpg',
#  'dataset_Gloom2.jpg',
#  'dataset_Gloom3.jpg',
#  'dataset_Gloom1.jpg',
#  'dataset_Gloom7.jpg',
#  'dataset_Gloom12.jpg',
#  'dataset_Gloom13.jpg',
#  'dataset_Gloom11.jpg',
#  'dataset_Gloom14.jpg',
#  'dataset_Gloom29.jpg',
#  'dataset_Gloom15.jpg',
#  'dataset_Gloom17.jpg',
#  'dataset_Gloom16.jpg',
#  'dataset_Charmeleon14.jpg',
#  'dataset_Charmeleon15.jpg',
#  'dataset_Charmeleon11.jpg',
#  'dataset_Charmeleon10.jpg',
#  'dataset_Charmeleon12.jpg',
#  'dataset_Charmeleon9.jpg',
#  'dataset_Charmeleon8.jpg',
#  'dataset_Charmeleon13.jpg',
#  'dataset_Charmeleon22.jpg',
#  'dataset_Charmeleon4.jpg',
#  'dataset_Charmeleon21.jpg',
#  'dataset_Charmeleon6.jpg',
#  'dataset_Charmeleon7.jpg',
#  'dataset_Charmeleon20.jpg',
#  'dataset_Charmeleon24.jpg',
#  'dataset_Charmeleon18.jpg',
#  'dataset_Charmeleon19.jpg',
#  'dataset_Charmeleon25.jpg',
#  'dataset_Charmeleon1.jpg',
#  'dataset_Articuno17.jpg',
#  'dataset_Articuno6.jpg',
#  'dataset_Articuno7.jpg',
#  'dataset_Articuno16.jpg',
#  'dataset_Articuno28.jpg',
#  'dataset_Articuno14.jpg',
#  'dataset_Articuno5.jpg',
#  'dataset_Articuno4.jpg',
#  'dataset_Articuno15.jpg',
#  'dataset_Articuno1.jpg',
#  'dataset_Articuno12.jpg',
#  'dataset_Articuno3.jpg',
#  'dataset_Articuno2.jpg',
#  'dataset_Articuno13.jpg',
#  'dataset_Articuno22.jpg',
#  'dataset_Articuno23.jpg',
#  'dataset_Articuno21.jpg',
#  'dataset_Articuno20.jpg',
#  'dataset_Articuno24.jpg',
#  'dataset_Articuno18.jpg',
#  'dataset_Articuno9.jpg',
#  'dataset_Articuno8.jpg',
#  'dataset_Articuno19.jpg',
#  'dataset_Articuno27.jpg',
#  'dataset_Articuno26.jpg',
#  'dataset_Sandshrew3.jpg',
#  'dataset_Sandshrew6.jpg',
#  'dataset_Sandshrew7.jpg',
#  'dataset_Sandshrew5.jpg',
#  'dataset_Sandshrew4.jpg',
#  'dataset_Sandshrew16.jpg',
#  'dataset_Sandshrew15.jpg',
#  'dataset_Sandshrew10.jpg',
#  'dataset_Sandshrew12.jpg',
#  'dataset_Sandshrew20.jpg',
#  'dataset_Sandshrew18.jpg',
#  'dataset_Sandshrew19.jpg',
#  'dataset_Sandshrew9.jpg',
#  'dataset_Spearow42.jpg',
#  'dataset_Spearow57.jpg',
#  'dataset_Spearow43.jpg',
#  'dataset_Spearow41.jpg',
#  'dataset_Spearow54.jpg',
#  'dataset_Spearow50.jpg',
#  'dataset_Spearow44.jpg',
#  'dataset_Spearow53.jpg',
#  'dataset_Spearow52.jpg',
#  'dataset_Spearow21.jpg',
#  'dataset_Spearow34.jpg',
#  'dataset_Spearow20.jpg',
#  'dataset_Spearow36.jpg',
#  'dataset_Spearow22.jpg',
#  'dataset_Spearow37.jpg',
#  'dataset_Spearow33.jpg',
#  'dataset_Spearow27.jpg',
#  'dataset_Spearow8.jpg',
#  'dataset_Spearow26.jpg',
#  'dataset_Spearow32.jpg',
#  'dataset_Spearow24.jpg',
#  'dataset_Spearow30.jpg',
#  'dataset_Spearow25.jpg',
#  'dataset_Spearow19.jpg',
#  'dataset_Spearow14.jpg',
#  'dataset_Spearow29.jpg',
#  'dataset_Spearow17.jpg',
#  'dataset_Spearow5.jpg',
#  'dataset_Spearow16.jpg',
#  'dataset_Spearow12.jpg',
#  'dataset_Spearow1.jpg',
#  'dataset_Spearow13.jpg',
#  'dataset_Spearow39.jpg',
#  'dataset_Spearow11.jpg',
#  'dataset_Spearow2.jpg',
#  'dataset_Spearow3.jpg',
#  'dataset_Spearow38.jpg',
#  'dataset_Spearow63.jpg',
#  'dataset_Spearow62.jpg',
#  'dataset_Spearow60.jpg',
#  'dataset_Spearow48.jpg',
#  'dataset_Spearow49.jpg',
#  'dataset_Spearow59.jpg',
#  'dataset_Spearow64.jpg',
#  'dataset_Spearow58.jpg',
#  'dataset_Spearow66.jpg',
#  'dataset_Spearow67.jpg',
#  'dataset_Marowak23.jpg',
#  'dataset_Marowak22.jpg',
#  'dataset_Marowak20.jpg',
#  'dataset_Marowak21.jpg',
#  'dataset_Marowak31.jpg',
#  'dataset_Marowak25.jpg',
#  'dataset_Marowak24.jpg',
#  'dataset_Marowak30.jpg',
#  'dataset_Marowak18.jpg',
#  'dataset_Marowak9.jpg',
#  'dataset_Marowak26.jpg',
#  'dataset_Marowak8.jpg',
#  'dataset_Marowak5.jpg',
#  'dataset_Marowak16.jpg',
#  'dataset_Marowak17.jpg',
#  'dataset_Marowak4.jpg',
#  'dataset_Marowak6.jpg',
#  'dataset_Marowak29.jpg',
#  'dataset_Marowak28.jpg',
#  'dataset_Marowak14.jpg',
#  'dataset_Marowak3.jpg',
#  'dataset_Marowak10.jpg',
#  'dataset_Marowak11.jpg',
#  'dataset_Marowak2.jpg',
#  'dataset_Marowak13.jpg',
#  'dataset_Marowak12.jpg',
#  'dataset_Marowak1.jpg',
#  'dataset_Clefairy33.jpg',
#  'dataset_Clefairy27.jpg',
#  'dataset_Clefairy26.jpg',
#  'dataset_Clefairy32.jpg',
#  'dataset_Clefairy18.jpg',
#  ...]

# %%
for image in image_list:
    if image in train_images:
        shutil.copyfile("data/dataset", "data/dataset/train")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 for image in image_list:
#       2     if image in train_images:
# ----> 3         shutil.copyfile("data/dataset", "data/dataset/train")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/middle-earth/lib/python3.8/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265         # macOS
#     266         if _HAS_FCOPYFILE:
#     267             try:
#
# IsADirectoryError: [Errno 21] Is a directory: 'data/dataset'

# %%
for label in class_labels:
    # move the train images into correct subfolder
    for image in train_images:
        src_path = os.path.join(label_dir, image)
        dst_path = os.path.join(train_dir, image)
        shutil.copyfile(src_path, dst_path)

    # move the test images into correct subfolder
    for image in test_images:
        src_path = os.path.join(label_dir, image)
        dst_path = os.path.join(test_dir, image)
        shutil.copyfile(src_path, dst_path)
